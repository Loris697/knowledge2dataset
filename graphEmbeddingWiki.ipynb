# %% [markdown]
# ## Install

# %%
# !pip install 'pykeen[tensorboard]'
# Out:
# Collecting pykeen[tensorboard]
#   Downloading pykeen-1.10.2-py3-none-any.whl (703 kB)
#      |████████████████████████████████| 703 kB 5.6 MB/s eta 0:00:01
# Collecting dataclasses-json
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Requirement already satisfied: pyyaml in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pykeen[tensorboard]) (6.0)
# Requirement already satisfied: scikit-learn in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pykeen[tensorboard]) (1.0.2)
# Collecting pystow>=0.4.3
#   Downloading pystow-0.5.4-py3-none-any.whl (32 kB)
# Requirement already satisfied: typing-extensions in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pykeen[tensorboard]) (4.9.0)
# Requirement already satisfied: tqdm in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pykeen[tensorboard]) (4.64.0)
# Requirement already satisfied: pandas>=1.0.0 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pykeen[tensorboard]) (1.4.2)
# Collecting torch-ppr>=0.0.7
#   Downloading torch_ppr-0.0.8-py3-none-any.whl (12 kB)
# Requirement already satisfied: requests in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pykeen[tensorboard]) (2.27.1)
# Requirement already satisfied: click in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pykeen[tensorboard]) (8.0.4)
# Collecting click-default-group
#   Downloading click_default_group-1.2.4-py2.py3-none-any.whl (4.1 kB)
# Requirement already satisfied: tabulate in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pykeen[tensorboard]) (0.8.9)
# Requirement already satisfied: numpy in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pykeen[tensorboard]) (1.21.5)
# Collecting more-click
#   Downloading more_click-0.1.2-py3-none-any.whl (6.7 kB)
# Requirement already satisfied: scipy>=1.7.0 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pykeen[tensorboard]) (1.7.3)
# Collecting docdata
#   Downloading docdata-0.0.3-py3-none-any.whl (5.8 kB)
# Collecting torch-max-mem>=0.1.1
#   Downloading torch_max_mem-0.1.3-py3-none-any.whl (10 kB)
# Collecting torch>=2.0
#   Downloading torch-2.2.2-cp39-none-macosx_10_9_x86_64.whl (150.8 MB)
#      |████████████████████████████████| 150.8 MB 14.4 MB/s eta 0:00:01
# Collecting more-itertools
#   Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 14.8 MB/s eta 0:00:01
# Collecting class-resolver>0.4.2
#   Downloading class_resolver-0.4.3-py3-none-any.whl (25 kB)
# Collecting optuna>=2.0.0
#   Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#      |████████████████████████████████| 380 kB 19.1 MB/s eta 0:00:01
# Requirement already satisfied: tensorboard in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pykeen[tensorboard]) (2.10.1)
# Requirement already satisfied: importlib-metadata>3.6 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from class-resolver>0.4.2->pykeen[tensorboard]) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>3.6->class-resolver>0.4.2->pykeen[tensorboard]) (3.7.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from optuna>=2.0.0->pykeen[tensorboard]) (1.4.32)
# Collecting colorlog
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 66.6 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from optuna>=2.0.0->pykeen[tensorboard]) (21.3)
# Collecting Mako
#   Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 24.8 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->optuna>=2.0.0->pykeen[tensorboard]) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->pykeen[tensorboard]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->pykeen[tensorboard]) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->pykeen[tensorboard]) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from sqlalchemy>=1.3.0->optuna>=2.0.0->pykeen[tensorboard]) (1.1.1)
# Requirement already satisfied: filelock in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from torch>=2.0->pykeen[tensorboard]) (3.6.0)
# Requirement already satisfied: sympy in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from torch>=2.0->pykeen[tensorboard]) (1.10.1)
# Requirement already satisfied: fsspec in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from torch>=2.0->pykeen[tensorboard]) (2022.2.0)
# Requirement already satisfied: jinja2 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from torch>=2.0->pykeen[tensorboard]) (2.11.3)
# Requirement already satisfied: networkx in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from torch>=2.0->pykeen[tensorboard]) (2.7.1)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.21.2-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 26.4 MB/s eta 0:00:01
# Collecting typing-inspect<1,>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->pykeen[tensorboard]) (0.4.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=2.0->pykeen[tensorboard]) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from requests->pykeen[tensorboard]) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from requests->pykeen[tensorboard]) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from requests->pykeen[tensorboard]) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from requests->pykeen[tensorboard]) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->pykeen[tensorboard]) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->pykeen[tensorboard]) (1.1.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from sympy->torch>=2.0->pykeen[tensorboard]) (1.2.1)
# Requirement already satisfied: wheel>=0.26 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from tensorboard->pykeen[tensorboard]) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from tensorboard->pykeen[tensorboard]) (1.33.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from tensorboard->pykeen[tensorboard]) (61.2.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from tensorboard->pykeen[tensorboard]) (2.0.3)
# Requirement already satisfied: absl-py>=0.4 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from tensorboard->pykeen[tensorboard]) (1.3.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from tensorboard->pykeen[tensorboard]) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from tensorboard->pykeen[tensorboard]) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from tensorboard->pykeen[tensorboard]) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from tensorboard->pykeen[tensorboard]) (0.6.0)
# Requirement already satisfied: protobuf in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from tensorboard->pykeen[tensorboard]) (3.19.1)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from tensorboard->pykeen[tensorboard]) (1.42.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->pykeen[tensorboard]) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->pykeen[tensorboard]) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->pykeen[tensorboard]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->pykeen[tensorboard]) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->pykeen[tensorboard]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/loriscino/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->pykeen[tensorboard]) (3.2.2)
# Installing collected packages: torch, Mako, typing-inspect, torch-max-mem, more-itertools, marshmallow, colorlog, alembic, torch-ppr, pystow, optuna, more-click, docdata, dataclasses-json, click-default-group, class-resolver, pykeen
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
# Successfully installed Mako-1.3.5 alembic-1.13.1 class-resolver-0.4.3 click-default-group-1.2.4 colorlog-6.8.2 dataclasses-json-0.6.6 docdata-0.0.3 marshmallow-3.21.2 more-click-0.1.2 more-itertools-10.2.0 optuna-3.6.1 pykeen-1.10.2 pystow-0.5.4 torch-2.2.2 torch-max-mem-0.1.3 torch-ppr-0.0.8 typing-inspect-0.9.0

# %% [markdown]
# ## Librerie

# %%
import json
import requests
import os
import pandas as pd
import numpy as np
import tarfile
import tqdm
#from pykeen.pipeline import pipeline
#from pykeen.predict import predict_all
#import torch
#from pykeen.evaluation import RankBasedEvaluator
#from pykeen.triples import TriplesFactory

IQS = False

# %% [markdown]
# ## Moduli

# %%
def fetch_labels_in_batches(ids, batch_size=50):
    # Prepare batches
    batches = [ids[i:i + batch_size] for i in range(0, len(ids), batch_size)]
    
    # Dictionary to hold the results
    labels_dict = {}
    
    for batch in batches:
        # Join IDs with '|' to form a single string for the API request
        batch_ids = '|'.join(batch)
        url = f"https://www.wikidata.org/w/api.php?action=wbgetentities&ids={batch_ids}&format=json&languages=en&props=labels"
        response = requests.get(url)
        data = response.json()
        
        # Extract labels for each entity in the batch
        for wikidata_id in batch:
            try:
                label = data['entities'][wikidata_id]['labels']['en']['value']
                labels_dict[wikidata_id] = label
            except KeyError:
                labels_dict[wikidata_id] = 'Label not found'  # Handle missing labels

    return labels_dict

# %%
def fetch_related_items(subject_qid):
    endpoint_url = "https://query.wikidata.org/sparql"
    query = f"""
    SELECT ?item ?itemLabel WHERE {{
      # ?item wdt:P31/wdt:P279* wd:{subject_qid}.
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
    }}
    LIMIT 10
    """

    headers = {"Accept": "application/json"}
    response = requests.get(endpoint_url, headers=headers, params={'query': query, 'format': 'json'})
    
    results = []
    if response.status_code == 200:
        data = response.json()
        results = [{'name': binding['itemLabel']['value'], 'qid': binding['item']['value'].split('/')[-1]}
                   for binding in data['results']['bindings']]

    return results

# %%
def download_file(url, destination):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            with open(destination, 'wb') as file:
                file.write(response.content)
            print("Download completato con successo.")
        else:
            print(f"Errore durante il download del file. Codice di stato: {response.status_code}")
    except Exception as e:
        print(f"Si è verificato un errore: {e}")


def decompress_tar_gz(file_path, destination_folder):
    try:

        with tarfile.open(file_path, 'r:gz') as tar:
            if not os.path.exists(destination_folder):
              os.mkdir(destination_folder)

            tar.extractall(destination_folder)
        print("Decompressione completata con successo.")
        return True
    except Exception as e:
        print(f"Si è verificato un errore durante la decompressione: {e}")
        return False


def read_firstlines(file_path, nlines):
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()[:nlines]
            for line in lines:
                print(line.rstrip())
    except FileNotFoundError:
        print(f"Il file '{file_path}' non esiste.")
    except Exception as e:
        print(f"Si è verificato un errore durante la lettura del file: {e}")


def itemQualityScore(item2search):
    inference_url = 'https://api.wikimedia.org/service/lw/inference/v1/models/wikidatawiki-itemquality:predict'

    try:
        req = requests.post(f"https://www.wikidata.org/w/api.php?action=query&format=json&formatversion=2&prop=revisions|entityterms&titles={item2search}&origin=*")
        jsonReq = req.json()

        data = {"rev_id": jsonReq['query']['pages'][0]['revisions'][0]['revid'] }
        response = requests.post(inference_url, headers=headers, data=json.dumps(data))
        prob = response.json()
        prediction = prob['wikidatawiki']['scores'][str(data['rev_id'])]['itemquality']['score']['prediction']
        probabilityFromModel = prob['wikidatawiki']['scores'][str(data['rev_id'])]['itemquality']['score']['probability'][prediction]
    except Exception as e:
        prediction = "NotFound"
        probabilityFromModel = 0


    return prediction, probabilityFromModel

# %%
def check_link_to_entity(entity_ids, subject_entity_id, batch_size=50):
    endpoint_url = "https://query.wikidata.org/sparql"
    linked_entities = []

    # Convert numpy array to list if needed
    if isinstance(entity_ids, np.ndarray):
        entity_ids = entity_ids.tolist()

    # Helper function to generate formatted entity strings
    def format_entities(batch):
        return " ".join(f"wd:{entity}" for entity in batch)

    # Process in batches
    for i in range(0, len(entity_ids), batch_size):
        batch = entity_ids[i:i + batch_size]
        formatted_entities = format_entities(batch)

        # SPARQL query to check link to specified subject entity
        query = f"""
        SELECT DISTINCT ?item WHERE {{
          VALUES ?item {{{formatted_entities}}}
          # ?item (wdt:P31/wdt:P279*)|wdt:P279* wd:{subject_entity_id}.
        }}
        """

        # Prepare headers for request
        headers = {"Accept": "application/json"}

        # Perform the request
        response = requests.get(endpoint_url, headers=headers, params={'query': query, 'format': 'json'})
        
        if response.status_code == 200:
            data = response.json()
            linked_entities.extend([result['item']['value'].split('/')[-1] for result in data['results']['bindings']])

    return linked_entities

# %%
def get_wikipedia_title(wikidata_id):
    """Fetch Wikipedia page title using Wikidata ID"""
    url = f"https://www.wikidata.org/w/api.php?action=wbgetentities&ids={wikidata_id}&props=sitelinks&sitefilter=enwiki&format=json"
    response = requests.get(url)
    data = response.json()
    title = data['entities'][wikidata_id]['sitelinks']['enwiki']['title']
    return title.replace(' ', '_')  # Replace spaces with underscores for the URL

def get_pageviews(title):
    """Fetch page views for a Wikipedia page title"""
    user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    url = f"https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/en.wikipedia/all-access/user/{title}/daily/20230101/20230131"
    response = requests.get(url, headers = {'User-Agent': user_agent})
    views = sum(day['views'] for day in response.json()['items'])
    return views

# %% [markdown]
# ## Dowload file wikidata

# %% [markdown]
# ### Triple codificate

# %%
url = "https://www.dropbox.com/s/6sbhm0rwo4l73jq/wikidata5m_transductive.tar.gz?dl=1"
destination = "wiki_tran.tar.gz"
download_file(url, destination)
decompress_tar_gz(destination, "./data")
os.remove("./wiki_tran.tar.gz")
# Out:
# Download completato con successo.
# Decompressione completata con successo.

# %% [markdown]
# ### Triple con sinonimi

# %%
url = "https://www.dropbox.com/s/7jp4ib8zo3i6m10/wikidata5m_text.txt.gz?dl=1"
# Sempre triple ma con i nomi
destination = "corpus.tar.gz"

download_file(url, destination)
decompress_tar_gz(destination, "./data")
os.remove("./corpus.tar.gz")
# Out:
# Download completato con successo.
# Si è verificato un errore durante la decompressione: invalid header

# %% [markdown]
# ### Alias delle entità

# %%
url = "https://www.dropbox.com/s/lnbhc8yuhit4wm5/wikidata5m_alias.tar.gz?dl=1"
destination = "alias.tar.gz"
download_file(url, destination)
decompress_tar_gz(destination, "./data")
os.remove("./alias.tar.gz")
# Out:
# Download completato con successo.
# Decompressione completata con successo.

# %% [markdown]
# ### Stampa delle prime righe dei file

# %%
for file in os.listdir("./data"):
    print(f"Prime righe di {file}")
    read_firstlines(f"./data/{file}", 3)
    print("\n")
# Out:
# Prime righe di wikidata5m_transductive_train.txt
# Q29387131	P31	Q5
# Q326660	P1412	Q652
# Q7339549	P57	Q1365729
#
#
# Prime righe di wikidata5m_relation.txt
# P489	currency symbol description
# P834	train depot	railway depot	depot	rail yard
# P2629	BBFC rating	BBFC certificate
#
#
# Prime righe di wikidata5m_transductive_valid.txt
# Q3576734	P495	Q30
# Q641724	P1412	Q1860
# Q959357	P39	Q49476
#
#
# Prime righe di wikidata5m_entity.txt
# Q5196650	Cut Your Hair	cut your hair
# Q912600	Straumur-Burðarás	Straumur	straumur–burðarás investment bank	straumur	Straumur-Burðarás Investment Bank	straumur-burðarás investment bank	straumur investment bank	straumur-burðarás fjárf.banki	Straumur-Burðarás Fjárf.banki	straumur-burðarás	Straumur Investment Bank	Straumur–Burðarás Investment Bank
# Q47551	ditiano	tipciano	titiaen geovene	Tizzianello	Called, Titian Tiziano Vecelli Cavaliere	called titian veccellio	genannt Vecelli Titian	Veccelli Titian genoemd Titiaan	titiano da cadore	ttiziano	dit Le Titien Titianus Vecellio	Tiziano Vecelli	Titiano Vecelli	tissien	Tiziano Vecelli da Cador	titiano vecelli	tizian vecellio	Tiçiano	titiaen	titian (tiziano veccellio)	tetian	ticciano	tiziano veccelli	ziano	Titien Vecelly	Ticciani	titiano vccello	Titien Vecelli da Cador	Tuziano	vicelli	tipziano	tizzani	Tisiaen	Tiziano Vecellio	tiziano veccellio	Tisiano	tishian	Tizano	vecelli	Titian (Tiziano Veccellio)	de Cador Titien Vecelli	Titien de Vecelli	ttalion	tiziano vecelli	tisciano	called Titian Veccellio	vecellio titian	dit le titien vecelli	tietsiaen	Tiziani	titianello	Titianus	Tittien-Vecelli	Titien	called Titian Tiziano Vecelli	Titianus Vecelly	tiçiano	tiziano vecelli da cadore	Titiano Veccelly	titiano d'uxellio dacadore	Ticianello	Ditiano	called titian tiziano vecelli	tician	Tiziano veccelli	titiaan giovene	titianesque	tiziano vecelli da cador	Tiziano Vecellio di Cadore	Titien Vecelli	titien vecelli	ticiano vecelio	tiziani	de Cador Titien de Vecelli	titians	genannt vecelli titian	Titiaan	titian vecelli	ou le Titien Titianus Vecellio	Titien Vecelli De Cador	vecelli da cadore	dit le Titien Titiano Vecelli da Cadore	Vecelli	Tizziano	Da Cadore	vecelli da cadore titian	tisiaen	Vecelli da Cadore	Thitsiaen	Vecelli da Cadore, Ven. Titian	titien vecelli da cador	titain	Titiano Vicelli	titiano vercelli	Vecelli da Cadore Titian	Titian Vecelli	Titiaen	tizian v.	tiziano vecellio di cadore	titianus	teriano vecellio	Tiziano Vecellio da Cadore stato Veneto	Titianesque	tit︠s︡iano vechellio	Ticiano	tizzianello	Titiaen Uccello	dit le titien titiano vecelli da cadore	Titiani	ticciani	Vecellio Titian	titiaen uccello	tittien-vecelli	Detiano	tiziano vecellio	tycjan	detiano	tiziano vecellio genannt tiziano	Tizzani	titien	titiano veccelly	Tit︠s︡iano Vechellio	ticijan	tishan	dit Le Titien Vecelli	Tiziano Vecellio Genannt Tiziano	tizano	Titian Vecelli da Cadore	Vecelio Ticiano	tuziano	Tizian	Ticijan	tissian	Titiano	Tishian	titiano	tizian vecelli	da cadore	tizian	Titianello	Tizziani	called, titian tiziano vecelli cavaliere	tiziano vecellio da cadore stato veneto	Tiziano Vicelli	vecelio ticiano	Le Titien	Titiano da Cadore	ou le titien titianus vecellio	Titain	ticiano	tiziano vicelli	de cador titien de vecelli	titian vecelli da cadore	Titiano d'Uxellio Dacadore	Titiano Vccello	tiziano vecelli cavaliere	tetiano	Tetiano	titiano vicelli	Ticciano	titsiaen	Titien Wecelli	de cador titien vecelli	tiziano veccelio	Vicelli	Titiano Vecellio	titien de vecelli	dit le titien titianus vecellio	Titien de Vecelli de Cador	Ttalion	Tisien	tizziani	tiziano	Titiaan Giovene	Tishan	titiano vecellio	titien vecelli de cador	Ziano	Tissian	tititian	Tician	Ticiano Vecelio	Tiziano Vecelli Cavaliere	tiziano vezelli	Titiaen Geovene	veccelli titian genoemd titiaan	thitsian	thitsiaen	le titien	Tiziano veccelio	titiaan	Tizian il più giovane	tit︠s︡ian	ttiçiano	Tiziano Veccellio	tisiano	titien de vecelli de cador	Tisciano	tizian il più giovane	tizziano	Thitsian	Tetian	Titiano Vercelli	Tiziano Vecelli da Cadore	Titsiaen	titiani	titien wecelli	titianus vecelly	Titian	ticianello	titian	Tissien	Tietsiaen	Tititian	Tycjan	vecelli da cadore, ven. titian	Tiziano	titien vecelly	Tit︠s︡ian	tisien	tticiano
#
#
# Prime righe di wikidata5m_transductive_test.txt
# Q7965079	P27	Q16
# Q6719921	P31	Q11446
# Q4925109	P175	Q5165801

# %% [markdown]
# ## API wikidata

# %%
headers = {
    'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....NnXfiaq4StcjEq9fqjVRUrJnn5m-eIDy6jQtLTwprH_huGrzm8Z6HduKUiE93a3zwQ3T3t2c8EV4VzDHWv-fPSfozhNVVhwzBhNI80qyMYJQb2ieSu0Jq0mobtY443ygnPDWhADV0QhMpgLpafUPA8QpjnfzmSpXzfWkiEj1oWnuMJ25cr4Y7jqTUjlLQ_wHHSS43DWX1ZURmC0tQb2fZJ0o1NdoiC5MTtcaEqB3t2zF_C1BNGB_jLcrqkYKMZwjDL4SSaph5vIVS9mpYJHaoPlkroKnsc66_75541eSrt5D5YHwkYNavNrvFYpDWVnzUCp5kfX5POaqMquHYEYIaTNJImVuY-2hXIvwkF4FG9rh6rt8Y7WY67Sf_wFhVN9LYqMZVlR3JnZzeI-wfPy_MZ2Wh-WeTb6FHJDow66hwBNX8ua5EfOEF3XOj1N4k5iwYSRSCW6Ko1we-MlExWRMRKFS9t1Rfaw1C8wJCWJRfm0TIZkl-1nP5ACr5w9d1n9S1qjp95HEMnb25aUG3N1q0zwg9nS7xoAqWHXoojoLg31ocSpvpe6Qb1lrolKJwI6GnSjJJAYG03tTejgTjLfBON4uJlEaHFi5rk867L5Hiz25HY3h-OlS5DabwMdH9hZnvipPPeslG9e4X3TgqtidVlPWSk3DSH3Fm_ZeHuZ-7EY',
    'Content-type': 'Content-type',
    'User-Agent': 'tumnus7@gmail.com'
}

# %% [markdown]
# ### Test API prediction

# %%
item2search = "Q35610"

# %%
pred, prob = itemQualityScore(item2search)

# %%
print(pred, prob)
# Out:
# A 0.9308966801692856

# %% [markdown]
# ## Data Loading e scrematura

# %%
#Set a min count to have a smaller dataset and avoid non-meaningful embedding
min_occ = 30

# %%
df_org_train = pd.read_csv('data/wikidata5m_transductive_train.txt', sep='\t', header=None, names=["head", "rel", "tail"])
df_org_valid = pd.read_csv('data/wikidata5m_transductive_valid.txt', sep='\t', header=None, names=["head", "rel", "tail"])
df_org_test = pd.read_csv('data/wikidata5m_transductive_test.txt', sep='\t', header=None, names=["head", "rel", "tail"])

# %%
(df_org_train.groupby("rel").count()['tail'] > min_occ).sum()
# Out:
# 563

# %%
#Element in head more common than 'min_occ'
grouped_head = df_org_train.groupby("head").count().rel 
most_common_head = np.array(grouped_head[grouped_head > min_occ ].index)

#Element in tail more common than 'min_occ'
grouped_tail = df_org_train.groupby("tail").count().rel 
most_common_tail = np.array(grouped_tail[grouped_tail> min_occ ].index)

#Element in rel more common than 'min_occ'
grouped_rel = df_org_train.groupby("rel").count()['tail'] 
most_common_rel = np.array(grouped_rel[grouped_rel > min_occ ].index)

# %%
len(most_common_tail)
# Out:
# 44434

# %%
df_org_train_reduced = df_org_train[(df_org_train["head"].isin(most_common_head)) & (df_org_train["rel"].isin(most_common_rel)) & (df_org_train["tail"].isin(most_common_tail))]
df_org_valid_reduced = df_org_valid[(df_org_valid["head"].isin(most_common_head)) & (df_org_valid["rel"].isin(most_common_rel)) & (df_org_valid["tail"].isin(most_common_tail))]
df_org_test_reduced = df_org_test[(df_org_test["head"].isin(most_common_head)) & (df_org_test["rel"].isin(most_common_rel)) & (df_org_test["tail"].isin(most_common_tail))]

# %%
df_org_train_reduced
# Out:
#               head    rel     tail
# 52         Q898840   P161  Q450109
# 62        Q2530270  P1346  Q317358
# 70           Q1867   P190    Q1475
# 79         Q107761   P921    Q9402
# 125        Q152824  P1412    Q1860
# ...            ...    ...      ...
# 20614024  Q2155090    P31   Q11424
# 20614088  Q1064978  P1346  Q425821
# 20614149   Q259778   P123   Q94912
# 20614220   Q238866   P161  Q205707
# 20614224   Q184697   P106   Q36180
#
# [182038 rows x 3 columns]

# %%
# List of subjects
subjects_to_wikidata = {
    "Geography": "Q82794",
    "History": "Q309",
    "Mathematics": "Q395",
    "Literature": "Q7725634",
    "Computer Science": "Q21198",
    "Biology": "Q420",
    "Statistics": "Q12483",
    "Physics": "Q413",
    "Chemistry": "Q2329",
    "Medicine": "Q11190",
    "Economics": "Q8134",
    "Philosophy": "Q5891",
    "Psychology": "Q9418",
    "Music": "Q8255",
    "Cinema": "Q1458269",
    "Television": "Q15416",
    "Sport": "Q349"
}

# %%
unique_rel = np.unique(df_org_train_reduced.rel)
len(unique_rel)
# Out:
# 335

# %%
unique_object = np.unique(list(df_org_train_reduced['head']) + list(df_org_train_reduced['tail']))
len(unique_object)
# Out:
# 26347

# %%
rel_labels = fetch_labels_in_batches(unique_rel)
rel_labels
# Out:
# {'P1001': 'applies to jurisdiction',
#  'P101': 'field of work',
#  'P1018': 'language regulatory body',
#  'P102': 'member of political party',
#  'P1027': 'conferred by',
#  'P103': 'native language',
#  'P1038': 'relative',
#  'P1040': 'film editor',
#  'P1049': 'worshipped by',
#  'P1050': 'medical condition',
#  'P1056': 'product or material produced or service provided',
#  'P106': 'occupation',
#  'P1064': 'track gauge',
#  'P1066': 'student of',
#  'P1071': 'location of creation',
#  'P1072': 'readable file format',
#  'P1073': 'writable file format',
#  'P1075': 'rector',
#  'P108': 'employer',
#  'P1080': 'from narrative universe',
#  'P110': 'illustrator',
#  'P112': 'founded by',
#  'P113': 'airline hub',
#  'P114': 'airline alliance',
#  'P1142': 'political ideology',
#  'P118': 'league',
#  'P119': 'place of burial',
#  'P1192': 'connecting service',
#  'P1196': 'manner of death',
#  'P121': 'item operated',
#  'P122': 'basic form of government',
#  'P123': 'publisher',
#  'P126': 'maintained by',
#  'P1269': 'facet of',
#  'P127': 'owned by',
#  'P1290': 'godparent',
#  'P1299': 'depicted by',
#  'P1302': 'primary destinations',
#  'P1303': 'instrument',
#  'P1308': 'officeholder',
#  'P131': 'located in the administrative territorial entity',
#  'P1313': 'office held by head of government',
#  'P1336': 'territory claimed by',
#  'P134': 'Label not found',
#  'P1343': 'described by source',
#  'P1344': 'participant in',
#  'P1346': 'winner',
#  'P135': 'movement',
#  'P136': 'genre',
#  'P1365': 'replaces',
#  'P1366': 'replaced by',
#  'P137': 'operator',
#  'P1376': 'capital of',
#  'P138': 'named after',
#  'P1383': 'contains settlement',
#  'P1387': 'political alignment',
#  'P1399': 'convicted of',
#  'P140': 'religion or worldview',
#  'P1408': 'licensed to broadcast to',
#  'P1411': 'nominated for',
#  'P1412': 'languages spoken, written or signed',
#  'P1414': 'GUI toolkit or framework',
#  'P1416': 'affiliation',
#  'P1427': 'start point',
#  'P1431': 'executive producer',
#  'P1434': 'takes place in fictional universe',
#  'P1435': 'heritage designation',
#  'P144': 'based on',
#  'P1441': 'present in work',
#  'P1444': 'destination point',
#  'P1445': 'fictional universe described in',
#  'P1454': 'legal form',
#  'P149': 'architectural style',
#  'P150': 'contains the administrative territorial entity',
#  'P1532': 'country for sport',
#  'P1533': 'family name identical to this given name',
#  'P1542': 'has effect',
#  'P1547': 'depends on software',
#  'P155': 'follows',
#  'P156': 'followed by',
#  'P1560': 'given name version for other gender',
#  'P1576': 'lifestyle',
#  'P1589': 'lowest point',
#  'P159': 'headquarters location',
#  'P1595': 'charge',
#  'P16': 'transport network',
#  'P161': 'cast member',
#  'P162': 'producer',
#  'P1654': 'wing configuration',
#  'P166': 'award received',
#  'P17': 'country',
#  'P170': 'creator',
#  'P1716': 'brand',
#  'P172': 'ethnic group',
#  'P175': 'performer',
#  'P176': 'manufacturer',
#  'P178': 'developer',
#  'P179': 'part of the series',
#  'P180': 'depicts',
#  'P1809': 'choreographer',
#  'P1830': 'owner of',
#  'P184': 'doctoral advisor',
#  'P185': 'doctoral student',
#  'P186': 'made from material',
#  'P1875': 'represented by',
#  'P1877': 'after a work by',
#  'P1884': 'hair color',
#  'P1889': 'different from',
#  'P189': 'location of discovery',
#  'P1891': 'signatory',
#  'P19': 'place of birth',
#  'P190': 'twinned administrative body',
#  'P1906': 'office held by head of state',
#  'P1923': 'participating team',
#  'P194': 'legislative body',
#  'P195': 'collection',
#  'P1950': 'second family name in Spanish name',
#  'P1962': 'Label not found',
#  'P199': 'business division',
#  'P1990': 'species kept',
#  'P1995': 'health specialty',
#  'P20': 'place of death',
#  'P205': 'basin country',
#  'P206': 'located in or next to body of water',
#  'P2061': 'aspect ratio (W:H)',
#  'P2079': 'fabrication method',
#  'P208': 'executive body',
#  'P2094': 'competition class',
#  'P21': 'sex or gender',
#  'P2175': 'medical condition treated',
#  'P2176': 'drug or therapy used for treatment',
#  'P2184': 'history of topic',
#  'P22': 'father',
#  'P2238': 'official symbol',
#  'P2283': 'uses',
#  'P2321': 'general classification of race participants',
#  'P2348': 'time period',
#  'P2358': 'Roman praenomen',
#  'P237': 'coat of arms',
#  'P2388': 'office held by head of the organization',
#  'P2389': 'organization directed by the office or position',
#  'P2408': 'set in period',
#  'P241': 'military branch',
#  'P2416': 'sports discipline competed in',
#  'P2438': 'narrator',
#  'P2439': 'Label not found',
#  'P248': 'stated in',
#  'P2499': 'league level above',
#  'P25': 'mother',
#  'P2500': 'league level below',
#  'P2512': 'has spin-off',
#  'P2515': 'costume designer',
#  'P2522': 'victory',
#  'P2541': 'operating area',
#  'P2554': 'production designer',
#  'P2563': 'superhuman feature or ability',
#  'P2564': 'Köppen climate classification',
#  'P2578': 'is the study of',
#  'P2596': 'culture',
#  'P26': 'spouse',
#  'P263': 'official residence',
#  'P2632': 'place of detention',
#  'P2633': 'geography of topic',
#  'P264': 'record label',
#  'P2650': 'interested in',
#  'P2652': 'partnership with',
#  'P2670': 'has part(s) of the class',
#  'P27': 'country of citizenship',
#  'P272': 'production company',
#  'P275': 'copyright license',
#  'P276': 'location',
#  'P277': 'programmed in',
#  'P2789': 'connects with',
#  'P279': 'subclass of',
#  'P282': 'writing system',
#  'P2852': 'emergency phone number',
#  'P2853': 'electrical plug type',
#  'P2860': 'cites work',
#  'P2868': 'subject has role',
#  'P287': 'designed by',
#  'P2925': 'domain of saint or deity',
#  'P2936': 'language used',
#  'P2962': 'title of chess person',
#  'P2989': 'has grammatical case',
#  'P2992': 'software quality assurance',
#  'P30': 'continent',
#  'P306': 'operating system',
#  'P3085': 'qualifies for event',
#  'P3092': 'film crew member',
#  'P31': 'instance of',
#  'P3174': 'art director',
#  'P3195': 'league points system',
#  'P3275': 'storyboard artist',
#  'P3300': 'musical conductor',
#  'P3301': 'broadcast by',
#  'P3373': 'sibling',
#  'P344': 'director of photography',
#  'P3448': 'stepparent',
#  'P3450': 'sports season of league or competition',
#  'P3461': 'designated as terrorist by',
#  'P3494': 'points classification',
#  'P3497': 'teams classification by time',
#  'P35': 'head of state',
#  'P355': 'has subsidiary',
#  'P36': 'capital',
#  'P360': 'is a list of',
#  'P3602': 'candidacy in election',
#  'P361': 'part of',
#  'P364': 'original language of film or TV show',
#  'P366': 'has use',
#  'P37': 'official language',
#  'P3701': 'incarnation of',
#  'P371': 'presenter',
#  'P38': 'currency',
#  'P3828': 'wears',
#  'P39': 'position held',
#  'P3919': 'contributed to creative work',
#  'P397': 'parent astronomical body',
#  'P398': 'child astronomical body',
#  'P40': 'child',
#  'P400': 'platform',
#  'P403': 'mouth of the watercourse',
#  'P404': 'game mode',
#  'P407': 'language of work or name',
#  'P408': 'software engine',
#  'P410': 'military rank',
#  'P411': 'canonization status',
#  'P412': 'voice type',
#  'P413': 'position played on team / speciality',
#  'P4132': 'linguistic typology',
#  'P414': 'stock exchange',
#  'P417': 'patron saint',
#  'P421': 'located in time zone',
#  'P4312': 'camera setup',
#  'P437': 'distribution format',
#  'P449': 'original broadcaster',
#  'P451': 'unmarried partner',
#  'P452': 'industry',
#  'P460': 'said to be the same as',
#  'P461': 'opposite of',
#  'P462': 'color',
#  'P463': 'member of',
#  'P466': 'occupant',
#  'P469': 'lake on watercourse',
#  'P47': 'shares border with',
#  'P479': 'input device',
#  'P485': 'archives at',
#  'P488': 'chairperson',
#  'P495': 'country of origin',
#  'P50': 'author',
#  'P500': 'exclave of',
#  'P501': 'enclave within',
#  'P509': 'cause of death',
#  'P511': 'honorific prefix',
#  'P512': 'academic degree',
#  'P520': 'armament',
#  'P521': 'scheduled service destination',
#  'P522': 'type of orbit',
#  'P527': 'has part(s)',
#  'P53': 'family',
#  'P530': 'diplomatic relation',
#  'P533': 'target',
#  'P54': 'member of sports team',
#  'P541': 'office contested',
#  'P542': 'officially opened by',
#  'P551': 'residence',
#  'P553': 'website account on',
#  'P559': 'terminus',
#  'P57': 'director',
#  'P58': 'screenwriter',
#  'P59': 'constellation',
#  'P598': 'commander of (DEPRECATED)',
#  'P6': 'head of government',
#  'P607': 'conflict',
#  'P608': 'exhibition history',
#  'P609': 'terminus location',
#  'P61': 'discoverer or inventor',
#  'P610': 'highest point',
#  'P611': 'religious order',
#  'P618': 'source of energy',
#  'P636': 'route of administration',
#  'P641': 'sport',
#  'P647': 'drafted by',
#  'P66': 'ancestral home',
#  'P664': 'organizer',
#  'P674': 'characters',
#  'P676': 'lyrics by',
#  'P689': 'afflicts',
#  'P69': 'educated at',
#  'P706': 'located in/on physical feature',
#  'P708': 'diocese',
#  'P710': 'participant',
#  'P725': 'voice actor',
#  'P726': 'candidate',
#  'P734': 'family name',
#  'P735': 'given name',
#  'P737': 'influenced by',
#  'P739': 'ammunition',
#  'P740': 'location of formation',
#  'P747': 'has edition or translation',
#  'P749': 'parent organization',
#  'P750': 'distributed by',
#  'P767': 'contributor to the creative work or subject',
#  'P769': 'significant drug interaction',
#  'P780': 'symptoms and signs',
#  'P793': 'significant event',
#  'P797': 'authority',
#  'P800': 'notable work',
#  'P802': 'student',
#  'P807': 'separated from',
#  'P81': 'connecting line',
#  'P822': 'mascot',
#  'P825': 'dedicated to',
#  'P828': 'has cause',
#  'P832': 'public holiday',
#  'P840': 'narrative location',
#  'P841': 'feast day',
#  'P85': 'anthem',
#  'P859': 'sponsor',
#  'P86': 'composer',
#  'P88': 'commissioned by',
#  'P885': 'origin of the watercourse',
#  'P91': 'sexual orientation',
#  'P915': 'filming location',
#  'P92': 'main regulatory text',
#  'P921': 'main subject',
#  'P927': 'anatomical location',
#  'P930': 'type of electrification',
#  'P931': 'place served by transport hub',
#  'P937': 'work location',
#  'P941': 'inspired by',
#  'P943': 'programmer',
#  'P945': 'allegiance',
#  'P97': 'noble title',
#  'P974': 'tributary'}

# %%
entity_labels = fetch_labels_in_batches(unique_object)
entity_labels

# %%
rel_dataframe = pd.DataFrame({
    "ID" : rel_labels.keys(),
    "name" : rel_labels.values(),
}).set_index('ID')
rel_dataframe.to_csv("common_relations.csv")
rel_dataframe

# %%
entity_dataframe = pd.DataFrame({
    "ID" : entity_labels.keys(),
    "name" : entity_labels.values(),
}).set_index('ID')
entity_dataframe

# %%
#for subject in subjects_to_wikidata:
#    # Fetch related items for Geography
#    related_items = fetch_related_items(subjects_to_wikidata[subject])
#    print(f"Related items to {subject}:")
#   for item in related_items:
#        print(f"{item['name']} (QID: {item['qid']})")

# %%
for subject in subjects_to_wikidata:
    linked_to_entity = check_link_to_entity(entity_dataframe.index, subjects_to_wikidata[subject], batch_size=50)
    print(subject, " : ", len(linked_to_entity))
    entity_dataframe[subject] = [1 if idx in linked_to_entity else 0 for idx in entity_dataframe.index]

# %%
entity_dataframe

# %%
for column in entity_dataframe.columns:
    if column != 'name':
        print(column, " : ", entity_dataframe[column].sum())

# %%
entity_dataframe.to_csv("common_entity_subjects.csv")

# %%
# Map Wikidata IDs to Wikipedia titles
titles = [get_wikipedia_title(wd_id) for wd_id in wikidata_ids]

# Get page views for each title
pageviews = {title: get_pageviews(title) for title in titles}

print(pageviews)
# Out:
# {'Douglas_Adams': 39271, 'Berlin': 149093, 'London': 485607}

# %%
wiki_train_path = 'data/wikidata5m_transductive_train_red.tsv'
df_org_train_reduced.to_csv(wiki_train_path, sep='\t', index=False)

wiki_validation_path = 'data/wikidata5m_transductive_valid_red.tsv'
#df_org_valid.to_csv(wiki_validation_path, sep='\t', index=False)

wiki_test_path = 'data/wikidata5m_transductive_test_red.tsv'
#df_org_test.to_csv(wiki_test_path, sep='\t', index=False)

# %% [markdown]
# ### Aggiungo ItemQualityScore

# %%
if IQS:
  parole_Q = []
  pred_Q = []

  checkpoint_interval = 500
  contatore_iterazioni = 0

  for pathData in [wiki_train_path, wiki_validation_path, wiki_test_path]:
    with open(pathData, 'r') as file:
        for riga in tqdm.tqdm(file):
            item2search = riga.split()[0]
            pred, prob = itemQualityScore(item2search)
            if pred == 'A' or pred == 'B':
                parole_Q.append(item2search)
                pred_Q.append(pred)

            contatore_iterazioni += 1

            if contatore_iterazioni % checkpoint_interval == 0:
                df_checkpoint = pd.DataFrame({'Entity': parole_Q, 'Score': pred_Q})

                df_checkpoint.to_csv(f"./data/checkpoint_{contatore_iterazioni}_{pathData.split('/')[1].split('.')[0]}_entity_score.csv", index=False)

                parole_Q = []
                pred_Q = []

    if parole_Q:
        df_checkpoint = pd.DataFrame({'Entity': parole_Q, 'Score': pred_Q})
        df_checkpoint.to_csv(f"./data/checkpoint_{contatore_iterazioni}_{pathData.split('/')[1].split('.')[0]}_entity_score.csv", index=False)

    df_finale = pd.concat([pd.read_csv(f"checkpoint_{i * checkpoint_interval}_{pathData.split('/')[1].split('.')[0]}_entity_score.csv") for i in range(1, (contatore_iterazioni // checkpoint_interval) + 1)], ignore_index=True)
    df_finale.to_csv(f"./data/{pathData.split('/')[1].split('.')[0]}_entity_score.csv", index=False)

# %% [markdown]
# ## Embedding

# %% [markdown]
# Spiegazione delle metriche [*qui*](https://docs.ampligraph.org/en/2.0.0/ampligraph.evaluation.html#metrics)

# %%
if 'df_org_train_reduced' not in globals():
    df_org_train_reduced = pd.read_csv('data/wikidata5m_transductive_train_red.tsv', sep='\t', header=None, names=["head", "rel", "tail"])

# %%
df4emb = df_org_train_reduced #pd.concat([df_org_train_reduced, df_org_valid, df_org_test], ignore_index=True)

triples_factory = TriplesFactory.from_labeled_triples(triples=df4emb[['head', 'rel', 'tail']].values)

training = triples_factory
validation = triples_factory
testing = triples_factory

d=training
id_to_entity={v: k for k, v in d.entity_to_id.items()}
id_to_relation={v: k for k, v in d.relation_to_id.items()}

triples_factory.triples
# Out:
# WARNING:pykeen.triples.triples_factory:Reconstructing all label-based triples. This is expensive and rarely needed.
# array([['Q100', 'P1376', 'Q771'],
#        ['Q100', 'P17', 'Q30'],
#        ['Q100', 'P190', 'Q1492'],
#        ...,
#        ['Q994', 'P190', 'Q656'],
#        ['Q994', 'P30', 'Q46'],
#        ['head', 'rel', 'tail']], dtype='<U9')

# %%
evaluator = RankBasedEvaluator()
emb_dict={}
emb_list = ["PairRE", "ConvE", "QuatE"]
df_metrics=pd.DataFrame(columns=["Model", "Hits@1", "Hits@3", "Hits@5", "Hits@10", "MRR"])
for emb in emb_list:
    print(f"\nStart with {emb}\n")
    try:
        result = pipeline(
            training=training,
            validation=validation,
            testing=testing,
            model=emb,
            device='gpu',
            random_seed=42,
            result_tracker='tensorboard',
            result_tracker_kwargs=dict(
                experiment_name=f'./log/wiki_{emb}',
            ),
        )
        result.save_to_directory(f'./evalModel/wiki_{emb}')
        metrics = evaluator.evaluate(result.model, testing.mapped_triples, additional_filter_triples=[training.mapped_triples, validation.mapped_triples])
        df_metrics['Model'] = emb
        df_metrics['Hits@1'] = metrics.get_metric('hits@1')
        df_metrics['Hits@3'] = metrics.get_metric('hits@3')
        df_metrics['Hits@5'] = metrics.get_metric('hits@5')
        df_metrics['Hits@10'] = metrics.get_metric('hits@10')
        df_metrics['MRR'] = metrics.get_metric('mean_reciprocal_rank')
        
        # Prediction
        pack = predict_all(model=result.model)
        prediction_all_triple = pack.process(factory=result.training)
        prediction_all_annotated = prediction_all_triple.add_membership_columns(training=result.training)

        df_metrics['MaxScore'] = prediction_all_annotated.df['score'].max()
        df_metrics['MinScore'] = prediction_all_annotated.df['score'].min()
        emb_dict[emb] = prediction_all_annotated
        
        triple_not_in_train = prediction_all_annotated.df[prediction_all_annotated.df['in_training']==False]

        triple_not_in_train.to_csv(f"./data/scored_predicted_triple_{emb}_notInTrain.csv", index=False)

    except Exception as e:
        print(f"Si è verificato un errore: {e}")
        continue
