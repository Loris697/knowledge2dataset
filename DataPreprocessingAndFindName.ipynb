# %%
import json
import requests
import os
import pandas as pd
import numpy as np
import tqdm
import matplotlib.pyplot as plt

# %%
def fetch_labels_in_batches(ids, batch_size=50):
    # Prepare batches
    batches = [ids[i:i + batch_size] for i in range(0, len(ids), batch_size)]

    # Dictionary to hold the results
    labels_dict = {}

    for batch in batches:
        # Join IDs with '|' to form a single string for the API request
        batch_ids = '|'.join(batch)
        url = f"https://www.wikidata.org/w/api.php?action=wbgetentities&ids={batch_ids}&format=json&languages=en&props=labels"
        response = requests.get(url)
        data = response.json()

        # Extract labels for each entity in the batch
        for wikidata_id in batch:
            try:
                label = data['entities'][wikidata_id]['labels']['en']['value']
                labels_dict[wikidata_id] = label
            except KeyError:
                labels_dict[wikidata_id] = 'Label not found'  # Handle missing labels

    return labels_dict

# %% [markdown]
# ## Data Loading

# %%
#Set a min count to have a smaller dataset and avoid non-meaningful embedding
min_occ = 5

# %%
df_most_clicked = pd.read_csv('data/most_clicked_pages.csv', header=0, names=["head", "rel", "tail"]).drop_duplicates().reset_index(drop=True)
df_most_clicked
# Out:
#               head    rel       tail
# 0       Q122921105    P31     Q11424
# 1       Q122921105   P495       Q668
# 2       Q122921105    P57   Q1607373
# 3       Q122921105   P364      Q1568
# 4       Q122921105    P86   Q7489036
# ...            ...    ...        ...
# 285019   Q20683904    P27       Q145
# 285020   Q20683904   P735  Q18131042
# 285021   Q20683904   P734  Q37471755
# 285022   Q20683904  P7763  Q73555012
# 285023   Q20683904  P1412      Q1860
#
# [285024 rows x 3 columns]

# %%
tail = df_most_clicked.groupby('tail').count()['head']
tail_repeated = tail[tail > min_occ]

# %%
len(tail_repeated)
# Out:
# 4833

# %%
df_most_clicked_reduced = df_most_clicked.query(' tail in @tail_repeated.index')

# %%
unique_rel = np.unique(df_most_clicked_reduced.rel)
len(unique_rel)
# Out:
# 450

# %%
unique_object = np.unique(list(df_most_clicked_reduced['head']) + list(df_most_clicked_reduced['tail']))
len(unique_object)
# Out:
# 13412

# %%
rel_labels = fetch_labels_in_batches(unique_rel)
rel_labels
# Out:
# {'P1001': 'applies to jurisdiction',
#  'P101': 'field of work',
#  'P102': 'member of political party',
#  'P1027': 'conferred by',
#  'P103': 'native language',
#  'P1035': 'honorific suffix',
#  'P1037': 'director / manager',
#  'P1038': 'relative',
#  'P1040': 'film editor',
#  'P1049': 'worshipped by',
#  'P105': 'taxon rank',
#  'P1050': 'medical condition',
#  'P10527': 'documentation files at',
#  'P1056': 'product or material produced or service provided',
#  'P10588': 'academic calendar type',
#  'P106': 'occupation',
#  'P10606': 'notable role',
#  'P10624': 'official observer status in organisation',
#  'P1066': 'student of',
#  'P1071': 'location of creation',
#  'P10741': 'dance style',
#  'P108': 'employer',
#  'P1080': 'from narrative universe',
#  'P11108': 'recorded participant',
#  'P112': 'founded by',
#  'P1142': 'political ideology',
#  'P115': 'home venue',
#  'P1158': 'location of landing',
#  'P11611': 'Norwegian media rating',
#  'P1165': 'home world',
#  'P11747': 'holds diplomatic passport of',
#  'P118': 'league',
#  'P119': 'place of burial',
#  'P1196': 'manner of death',
#  'P121': 'item operated',
#  'P122': 'basic form of government',
#  'P123': 'publisher',
#  'P12484': 'television judge',
#  'P126': 'maintained by',
#  'P1268': 'represents',
#  'P1269': 'facet of',
#  'P127': 'owned by',
#  'P129': 'physically interacts with',
#  'P1290': 'godparent',
#  'P1303': 'instrument',
#  'P1308': 'officeholder',
#  'P131': 'located in the administrative territorial entity',
#  'P1313': 'office held by head of government',
#  'P1327': 'partner in business or sport',
#  'P1336': 'territory claimed by',
#  'P1340': 'eye color',
#  'P1343': 'described by source',
#  'P1344': 'participant in',
#  'P1346': 'winner',
#  'P135': 'movement',
#  'P136': 'genre',
#  'P1363': 'points/goal scored by',
#  'P1365': 'replaces',
#  'P1366': 'replaced by',
#  'P137': 'operator',
#  'P1376': 'capital of',
#  'P138': 'named after',
#  'P1382': 'partially coincident with',
#  'P1387': 'political alignment',
#  'P1399': 'convicted of',
#  'P140': 'religion or worldview',
#  'P1408': 'licensed to broadcast to',
#  'P141': 'IUCN conservation status',
#  'P1411': 'nominated for',
#  'P1412': 'languages spoken, written or signed',
#  'P1416': 'affiliation',
#  'P1427': 'start point',
#  'P1431': 'executive producer',
#  'P1433': 'published in',
#  'P1434': 'takes place in fictional universe',
#  'P1435': 'heritage designation',
#  'P144': 'based on',
#  'P1441': 'present in work',
#  'P1444': 'destination point',
#  'P1445': 'fictional universe described in',
#  'P1454': 'legal form',
#  'P1479': 'has contributing factor',
#  'P150': 'contains the administrative territorial entity',
#  'P1532': 'country for sport',
#  'P1535': 'used by',
#  'P1537': 'contributing factor of',
#  'P1542': 'has effect',
#  'P155': 'follows',
#  'P1552': 'has characteristic',
#  'P1557': 'manifestation of',
#  'P156': 'followed by',
#  'P157': 'killed by',
#  'P1576': 'lifestyle',
#  'P1589': 'lowest point',
#  'P159': 'headquarters location',
#  'P1591': 'defendant',
#  'P1595': 'charge',
#  'P1596': 'penalty',
#  'P1605': 'has natural reservoir',
#  'P161': 'cast member',
#  'P162': 'producer',
#  'P1620': 'plaintiff',
#  'P1622': 'driving side',
#  'P1657': 'MPA film rating',
#  'P166': 'award received',
#  'P169': 'chief executive officer',
#  'P17': 'country',
#  'P170': 'creator',
#  'P172': 'ethnic group',
#  'P175': 'performer',
#  'P176': 'manufacturer',
#  'P178': 'developer',
#  'P179': 'part of the series',
#  'P180': 'depicts',
#  'P183': 'endemic to',
#  'P1830': 'owner of',
#  'P1853': 'blood type',
#  'P186': 'made from material',
#  'P1875': 'represented by',
#  'P1877': 'after a work by',
#  'P1884': 'hair color',
#  'P1889': 'different from',
#  'P1891': 'signatory',
#  'P19': 'place of birth',
#  'P190': 'twinned administrative body',
#  'P1906': 'office held by head of state',
#  'P1923': 'participating team',
#  'P194': 'legislative body',
#  'P195': 'collection',
#  'P1950': 'second family name in Spanish name',
#  'P1951': 'investor',
#  'P1981': 'FSK film rating',
#  'P1995': 'health specialty',
#  'P20': 'place of death',
#  'P205': 'basin country',
#  'P206': 'located in or next to body of water',
#  'P2061': 'aspect ratio (W:H)',
#  'P2079': 'fabrication method',
#  'P208': 'executive body',
#  'P2094': 'competition class',
#  'P2098': 'substitute/deputy/replacement of office/officeholder',
#  'P21': 'sex or gender',
#  'P2175': 'medical condition treated',
#  'P22': 'father',
#  'P2283': 'uses',
#  'P2341': 'indigenous to',
#  'P2348': 'time period',
#  'P2354': 'has list',
#  'P2360': 'intended public',
#  'P2363': 'NMHH film rating',
#  'P2378': 'issued by',
#  'P2388': 'office held by head of the organization',
#  'P2408': 'set in period',
#  'P241': 'military branch',
#  'P2416': 'sports discipline competed in',
#  'P2438': 'narrator',
#  'P2499': 'league level above',
#  'P25': 'mother',
#  'P2500': 'league level below',
#  'P2501': 'results',
#  'P2515': 'costume designer',
#  'P2522': 'victory',
#  'P2541': 'operating area',
#  'P2545': 'bowling style',
#  'P2563': 'superhuman feature or ability',
#  'P2596': 'culture',
#  'P26': 'spouse',
#  'P2629': 'BBFC rating',
#  'P263': 'official residence',
#  'P2632': 'place of detention',
#  'P2637': 'RARS rating',
#  'P264': 'record label',
#  'P2643': 'Carnegie Classification of Institutions of Higher Education',
#  'P2650': 'interested in',
#  'P2652': 'partnership with',
#  'P2670': 'has part(s) of the class',
#  'P2684': 'Kijkwijzer rating',
#  'P27': 'country of citizenship',
#  'P2715': 'elected in',
#  'P272': 'production company',
#  'P2737': 'union of',
#  'P2738': 'disjoint union of',
#  'P2747': 'Filmiroda rating',
#  'P275': 'copyright license',
#  'P2756': 'EIRIN film rating',
#  'P2758': 'CNC film rating (France)',
#  'P276': 'location',
#  'P277': 'programmed in',
#  'P2770': 'source of income',
#  'P2789': 'connects with',
#  'P279': 'subclass of',
#  'P2852': 'emergency phone number',
#  'P2853': 'electrical plug type',
#  'P286': 'head coach',
#  'P2868': 'subject has role',
#  'P287': 'designed by',
#  'P2894': 'day of week',
#  'P291': 'place of publication',
#  'P2922': 'month of the year',
#  'P2925': 'domain of saint or deity',
#  'P2936': 'language used',
#  'P30': 'continent',
#  'P306': 'operating system',
#  'P3075': 'official religion',
#  'P3081': 'damaged',
#  'P3082': 'destroyed',
#  'P3092': 'film crew member',
#  'P3095': 'practiced by',
#  'P31': 'instance of',
#  'P3150': 'birthday',
#  'P3156': 'Australian Classification',
#  'P3174': 'art director',
#  'P3179': 'territory overlaps',
#  'P3216': 'ClassInd rating',
#  'P3275': 'storyboard artist',
#  'P3279': 'statistical leader',
#  'P3300': 'musical conductor',
#  'P3301': 'broadcast by',
#  'P3306': 'ICAA rating',
#  'P3320': 'board member',
#  'P3342': 'significant person',
#  'P3373': 'sibling',
#  'P3402': 'CNC film rating (Romania)',
#  'P3403': 'coextensive with',
#  'P3428': 'INCAA film rating',
#  'P344': 'director of photography',
#  'P3448': 'stepparent',
#  'P3450': 'sports season of league or competition',
#  'P3461': 'designated as terrorist by',
#  'P3494': 'points classification',
#  'P3496': 'teams classification by points',
#  'P35': 'head of state',
#  'P355': 'has subsidiary',
#  'P36': 'capital',
#  'P360': 'is a list of',
#  'P3602': 'candidacy in election',
#  'P361': 'part of',
#  'P364': 'original language of film or TV show',
#  'P3650': 'JMK film rating',
#  'P366': 'has use',
#  'P37': 'official language',
#  'P371': 'presenter',
#  'P3716': 'social classification',
#  'P3730': 'next higher rank',
#  'P3764': 'pole position',
#  'P38': 'currency',
#  'P3803': 'original film format',
#  'P3818': 'KMRB film rating',
#  'P3834': 'RTC film rating',
#  'P3842': 'located in the present-day administrative territorial entity',
#  'P39': 'position held',
#  'P3919': 'contributed to creative work',
#  'P3931': 'copyright holder',
#  'P397': 'parent astronomical body',
#  'P3989': 'members have occupation',
#  'P40': 'child',
#  'P400': 'platform',
#  'P404': 'game mode',
#  'P407': 'language of work or name',
#  'P408': 'software engine',
#  'P410': 'military rank',
#  'P4101': 'dissertation submitted to',
#  'P411': 'canonization status',
#  'P412': 'voice type',
#  'P413': 'position played on team / speciality',
#  'P414': 'stock exchange',
#  'P4151': 'game mechanics',
#  'P417': 'patron saint',
#  'P4185': 'iconographic symbol',
#  'P421': 'located in time zone',
#  'P4224': 'category contains',
#  'P423': 'shooting handedness',
#  'P4312': 'camera setup',
#  'P4330': 'contains',
#  'P4353': 'nominated by',
#  'P437': 'distribution format',
#  'P4387': 'update method',
#  'P4437': 'FPB rating',
#  'P449': 'original broadcaster',
#  'P451': 'unmarried partner',
#  'P452': 'industry',
#  'P457': 'foundational text',
#  'P460': 'said to be the same as',
#  'P461': 'opposite of',
#  'P462': 'color',
#  'P463': 'member of',
#  'P4646': 'representation of',
#  'P466': 'occupant',
#  'P467': 'legislated by',
#  'P47': 'shares border with',
#  'P479': 'input device',
#  'P4794': 'season starts',
#  'P485': 'archives at',
#  'P488': 'chairperson',
#  'P495': 'country of origin',
#  'P4969': 'derivative work',
#  'P50': 'author',
#  'P500': 'exclave of',
#  'P5004': 'in opposition to',
#  'P5008': 'on focus list of Wikimedia project',
#  'P5009': 'complies with',
#  'P501': 'enclave within',
#  'P5021': 'assessment',
#  'P504': 'shipping port',
#  'P5053': 'fastest lap',
#  'P509': 'cause of death',
#  'P511': 'honorific prefix',
#  'P512': 'academic degree',
#  'P5138': 'season of club or team',
#  'P5150': 'IGAC rating',
#  'P518': 'applies to part',
#  'P520': 'armament',
#  'P5201': 'IMDA rating',
#  'P527': 'has part(s)',
#  'P53': 'family',
#  'P530': 'diplomatic relation',
#  'P532': 'port of registry',
#  'P533': 'target',
#  'P5389': 'permanent resident of',
#  'P54': 'member of sports team',
#  'P541': 'office contested',
#  'P547': 'commemorates',
#  'P551': 'residence',
#  'P552': 'handedness',
#  'P553': 'website account on',
#  'P559': 'terminus',
#  'P5642': 'risk factor',
#  'P5658': 'railway traffic side',
#  'P57': 'director',
#  'P5707': 'samples from work',
#  'P58': 'screenwriter',
#  'P5800': 'narrative role',
#  'P5970': 'Medierådet rating',
#  'P5995': 'kit supplier',
#  'P6': 'head of government',
#  'P607': 'conflict',
#  'P6087': 'coach of sports team',
#  'P61': 'discoverer or inventor',
#  'P6104': 'maintained by WikiProject',
#  'P6106': 'uses capitalization for',
#  'P6118': 'season ends',
#  'P6153': 'research site',
#  'P6216': 'copyright status',
#  'P6259': 'epoch',
#  'P6275': 'copyright representative',
#  'P629': 'edition or translation of',
#  'P6291': 'advertises',
#  'P634': 'team captain',
#  'P6364': 'official color',
#  'P6379': 'has works in the collection',
#  'P641': 'sport',
#  'P6452': 'CBFC rating',
#  'P647': 'drafted by',
#  'P6477': 'does not have characteristic',
#  'P65': 'site of astronomical discovery',
#  'P6531': 'observed in',
#  'P655': 'translator',
#  'P6553': 'personal pronoun',
#  'P66': 'ancestral home',
#  'P664': 'organizer',
#  'P6658': 'RCQ classification',
#  'P674': 'characters',
#  'P6758': 'supported sports team',
#  'P676': 'lyrics by',
#  'P6872': 'has written for',
#  'P6886': 'writing language',
#  'P689': 'afflicts',
#  'P69': 'educated at',
#  'P6942': 'animator',
#  'P6978': 'Scandinavian middle family name',
#  'P7047': 'enemy',
#  'P706': 'located in/on physical feature',
#  'P710': 'participant',
#  'P725': 'voice actor',
#  'P726': 'candidate',
#  'P7327': 'OFLC classification',
#  'P734': 'family name',
#  'P735': 'given name',
#  'P737': 'influenced by',
#  'P7378': 'item disputed by',
#  'P740': 'location of formation',
#  'P741': 'playing hand',
#  'P748': 'appointed by',
#  'P749': 'parent organization',
#  'P750': 'distributed by',
#  'P7501': 'audio system',
#  'P7573': 'IFCO rating',
#  'P767': 'contributor to the creative work or subject',
#  'P7763': 'copyright status as a creator',
#  'P7781': 'exonerated of',
#  'P780': 'symptoms and signs',
#  'P787': 'spore print color',
#  'P793': 'significant event',
#  'P7937': 'form of creative work',
#  'P7959': 'historic county',
#  'P797': 'authority',
#  'P800': 'notable work',
#  'P8017': 'generational suffix',
#  'P8031': 'perpetrator',
#  'P8032': 'victim',
#  'P8047': 'country of registry',
#  'P807': 'separated from',
#  'P8115': 'eligible recipient',
#  'P8127': 'tournament format',
#  'P8138': 'located in statistical territorial entity',
#  'P825': 'dedicated to',
#  'P828': 'has cause',
#  'P832': 'public holiday',
#  'P8324': 'funder',
#  'P8345': 'media franchise',
#  'P837': 'day in year for periodic occurrence',
#  'P8371': 'references work, tradition or theory',
#  'P840': 'narrative location',
#  'P841': 'feast day',
#  'P8411': 'set in environment',
#  'P85': 'anthem',
#  'P852': 'ESRB rating',
#  'P853': 'CERO rating',
#  'P859': 'sponsor',
#  'P86': 'composer',
#  'P87': 'librettist',
#  'P88': 'commissioned by',
#  'P8874': 'Hong Kong film rating',
#  'P8889': 'MTRCB rating',
#  'P8956': 'compatible with',
#  'P9028': 'CCC classification',
#  'P9071': 'character type',
#  'P908': 'PEGI rating',
#  'P9086': 'BAMID film rating',
#  'P91': 'sexual orientation',
#  'P9139': 'first family name in Portuguese name',
#  'P914': 'USK rating',
#  'P915': 'filming location',
#  'P916': 'GSRR rating',
#  'P92': 'main regulatory text',
#  'P921': 'main subject',
#  'P9215': 'set during recurring event',
#  'P924': 'possible treatment',
#  'P937': 'work location',
#  'P941': 'inspired by',
#  'P9419': 'personal library at',
#  'P945': 'allegiance',
#  'P9493': 'artist files at',
#  'P9600': 'oral history at',
#  'P967': 'guest of honor',
#  'P97': 'noble title',
#  'P9714': 'taxon range',
#  'P9866': 'GRAC rating',
#  'P991': 'successful candidate',
#  'P9929': 'madhhab'}

# %%
entity_labels = fetch_labels_in_batches(unique_object)
entity_labels
# Out:
# {'L252247-F2': 'Label not found',
#  'L371': 'Label not found',
#  'L484': 'Label not found',
#  'L485': 'Label not found',
#  'L615860-F1': 'Label not found',
#  'Q100': 'Boston',
#  'Q1000': 'Gabon',
#  'Q1000219': 'Kapoor family',
#  'Q1000592': 'Tyson Fury',
#  'Q1001': 'Mahatma Gandhi',
#  'Q100137722': 'Wikiproject Nuremberg Trials',
#  'Q100144350': 'Nicolas Jackson',
#  'Q100193610': 'Jahmyr Gibbs',
#  'Q100268160': 'The Mole – Undercover in North Korea',
#  'Q100292174': 'Books of Blood',
#  'Q100361125': 'Furiosa: A Mad Max Saga',
#  'Q1004037': 'Frederik X of Denmark',
#  'Q100408299': 'Kyren Williams',
#  'Q100437698': 'murder of Samuel Paty',
#  'Q1005': 'The Gambia',
#  'Q1005887': 'Fórum Hungary',
#  'Q1005953': 'Midland',
#  'Q100598166': 'Saurabh Sachdeva',
#  'Q100598223': 'Kathleen Biden',
#  'Q100598230': 'Melissa Cohen',
#  'Q1006': 'Guinea',
#  'Q100604534': 'Greg Brockman',
#  'Q100605126': 'Naomi Biden',
#  'Q10068': 'Lindsey Vonn',
#  'Q1007': 'Guinea-Bissau',
#  'Q100704907': 'Tiger 3',
#  'Q100711980': 'Category I',
#  'Q100711983': 'Category IIA',
#  'Q100718706': '2023 New Zealand general election',
#  'Q100719358': 'Hunter Dickinson',
#  'Q100736066': 'Belfast',
#  'Q100795875': 'Blake Corum',
#  'Q1008': 'Ivory Coast',
#  'Q100877419': 'emir of Kuwait',
#  'Q1009': 'Cameroon',
#  'Q10090': 'Hindu',
#  'Q100901254': 'Scotty Pippen Jr.',
#  'Q100909225': 'Austin Reaves',
#  'Q100937': 'Fred Astaire',
#  'Q100963892': 'Glenn Youngkin',
#  'Q101002778': 'Terrifier 2',
#  'Q101079395': 'Patchy Mix',
#  'Q101083924': 'Farmer–Citizen Movement',
#  'Q101084272': 'Clayton Tune',
#  'Q101093537': "Dark Archives: A Librarian's Investigation into the Science and History of Books Bound in Human Skin",
#  'Q1011': 'Cape Verde',
#  'Q101110072': '2024 United States presidential election',
#  'Q101114597': 'Stetson Bennett',
#  'Q1011509': 'Golden Globe Award for Best Motion Picture – Drama',
#  'Q1011547': 'Golden Globe Awards',
#  'Q1011564': 'Golden Globe Award for Best Actress in a Motion Picture – Musical or Comedy',
#  'Q101209661': 'Enumclaw horse sex case',
#  'Q101229278': 'Tagir Ulanbekov',
#  'Q101229345': 'Desmond Ridder',
#  'Q101242891': 'honorary doctor of the Hofstra University',
#  'Q101246526': 'Iedereen Leest',
#  'Q1013': 'Lesotho',
#  'Q10132': 'Rafael Nadal',
#  'Q1014': 'Liberia',
#  'Q101424698': 'Four Seasons Total Landscaping press conference',
#  'Q101428652': 'Jasmine Crockett',
#  'Q101503854': 'Michael Penix Jr.',
#  'Q1015874': 'Sherman Oaks',
#  'Q1016': 'Libya',
#  'Q101638': 'Mary Wollstonecraft',
#  'Q101658304': 'Thomas Gabriel',
#  'Q101730': '1998 FIFA World Cup',
#  'Q101751': '1994 FIFA World Cup',
#  'Q10179': 'Zulu',
#  'Q101797': 'Winona Ryder',
#  'Q101837349': 'Manning family',
#  'Q101898470': 'mystery television series',
#  'Q1019': 'Madagascar',
#  'Q1019496': 'Moose Jaw',
#  'Q1020': 'Malawi',
#  'Q1020011': 'Lavrentiya',
#  'Q102036557': 'list of The Crown episodes',
#  'Q102046208': 'Home Sweet Home Alone',
#  'Q102088683': 'Peter Seidler',
#  'Q102089542': 'The Game Awards 2021',
#  'Q102108194': 'G',
#  'Q102108196': 'Parental Guidance',
#  'Q102108197': 'R-13',
#  'Q102108198': 'R-16',
#  'Q102110778': 'Champ Kelly',
#  'Q102124': 'Sigourney Weaver',
#  'Q1021386': 'civil rights advocate',
#  'Q102139': 'Margrethe II of Denmark',
#  'Q102142': 'Marianne Bachmeier',
#  'Q102147287': 'Vikram',
#  'Q102179077': 'Johan Bakayoko',
#  'Q10218': 'Rahul Gandhi',
#  'Q102180036': 'Riz Test',
#  'Q102202422': 'Sauce Gardner',
#  'Q1022094': 'Poptropica',
#  'Q1022208': 'NORAD Tracks Santa',
#  'Q102225197': 'Brandon Royval',
#  'Q10225': 'Indian National Congress',
#  'Q102251': 'Sephardi Jews',
#  'Q1022513': 'The Sound of Music',
#  'Q10230': 'Bharatiya Janata Party',
#  'Q102338984': 'Matt Rogers',
#  'Q102341': 'Farrah Fawcett',
#  'Q102355560': 'Mohammad Wasim',
#  'Q1023712': 'San Fernando',
#  'Q102396768': "2020–21 NCAA Division I men's basketball season",
#  'Q102425753': 'Connor Bedard',
#  'Q102427': 'Academy Award for Best Picture',
#  'Q102427314': 'Xochitl Gomez',
#  'Q10244': 'Diwali',
#  'Q1024426': 'University of South Carolina',
#  'Q102462': 'James Stewart',
#  'Q1025': 'Mauritania',
#  'Q1025481': 'Simbang Gabi',
#  'Q102605': 'Paul II',
#  'Q1026827': 'California Institute of the Arts',
#  'Q1026939': 'California State University, Northridge',
#  'Q1027': 'Mauritius',
#  'Q102761': 'least common multiple',
#  'Q1027880': 'Grammy Award for Best Pop Duo/Group Performance',
#  'Q1027891': 'Grammy Award for Best Pop Vocal Album',
#  'Q1027904': 'Grammy Award for Song of the Year',
#  'Q10279996': 'Trapp family',
#  'Q1028': 'Morocco',
#  'Q102813': 'Yul Brynner',
#  'Q10281320': 'Fernando Diniz',
#  'Q1028181': 'painter',
#  'Q10285': 'Colosseum',
#  'Q1028601': 'Verdine White',
#  'Q102870': 'Harriet Tubman',
#  'Q1029': 'Mozambique',
#  'Q1029010': 'Guy Chambers',
#  'Q102920': 'UEFA Euro 2004',
#  'Q10294045': 'Hasty Pudding Woman of the Year',
#  'Q1029512': 'Camilo Villegas',
#  'Q1029706': 'New International Encyclopedia',
#  'Q1030': 'Namibia',
#  'Q10306813': 'Jesse Palmer',
#  'Q10307713': 'The Hunger Games: Mockingjay – Part 2',
#  'Q10315': 'Real Sociedad',
#  'Q103157': 'Kurt Russell',
#  'Q1031837': 'Goldfinch',
#  'Q1032': 'Niger',
#  'Q1032041': 'Haruki Muramatsu',
#  'Q1032175': 'Canadian Football League',
#  'Q10322797': 'MacKenzie Scott',
#  'Q103277': 'Sisinnius',
#  'Q10329': 'Sevilla FC',
#  'Q1033': 'Nigeria',
#  'Q1033140': "All Souls' Day",
#  'Q10333': 'Valencia CF',
#  'Q103343': 'Jennifer Connelly',
#  'Q103360': 'Academy Award for Best Director',
#  'Q1033692': 'Santa Monica College',
#  'Q1033891': 'martial arts film',
#  'Q10343045': 'PC Siqueira',
#  'Q10349745': 'racing automobile driver',
#  'Q103505599': 'WikiProject PCC Wikidata Pilot/Smithsonian Libraries Dibner Library portraits',
#  'Q1035067': 'Heisman Trophy',
#  'Q103569': 'Alien',
#  'Q103578': 'Macaulay Culkin',
#  'Q103582282': "Danny O'Carroll",
#  'Q1035954': 'heterosexuality',
#  'Q1036': 'Uganda',
#  'Q103610353': 'The Serpent',
#  'Q103618': 'Academy Award for Best Actress',
#  'Q103646': 'Ron Howard',
#  'Q103651': 'Glenn Miller',
#  'Q103665': 'Junior Eurovision Song Contest',
#  'Q1037': 'Rwanda',
#  'Q103784': 'Donald Sutherland',
#  'Q10384029': 'drug trafficker',
#  'Q103843006': 'A Biographical Dictionary of the Celebrated Women of Every Age and Country',
#  'Q103876': "Peter O'Toole",
#  'Q1038788': 'Hyatt Regency walkway collapse',
#  'Q1039': 'São Tomé and Príncipe',
#  'Q103916': 'Academy Award for Best Actor',
#  'Q103939': 'Charlie Sheen',
#  'Q103946': 'Kiefer Sutherland',
#  'Q104000': 'Lauren Bacall',
#  'Q104007235': 'Only Murders in the Building',
#  'Q104027': 'Kirk Douglas',
#  'Q1040342': 'list of shoe throwing incidents',
#  'Q104067': 'Eli Wallach',
#  'Q1040807': 'Lady Sarah Chatto',
#  'Q1041': 'Senegal',
#  'Q104112057': "Katy M. O'Brian",
#  'Q104117222': 'The Game Awards − Best Game Direction',
#  'Q104117223': 'The Game Awards − Best Narrative',
#  'Q104117224': 'The Game Awards − Best Art Direction',
#  'Q104117225': 'The Game Awards − Best Score and Music',
#  'Q104117226': 'The Game Awards − Best Audio Design',
#  'Q104117227': 'The Game Awards − Best Performance',
#  'Q104117241': 'The Game Awards − Best Action/Adventure',
#  'Q104117243': 'The Game Awards − Best Role Playing',
#  'Q104117248': 'The Game Awards − Best Multiplayer',
#  'Q104117254': 'The Game Awards − Content Creator of the Year',
#  'Q104117256': "The Game Awards − Player's Voice",
#  'Q104123': 'Pulp Fiction',
#  'Q104144087': 'Waithe Test',
#  'Q104144331': 'Tanveer Sangha',
#  'Q104144383': 'Shukla Test',
#  'Q104144557': 'Feldman Test',
#  'Q104144845': 'list of Jujutsu Kaisen episodes',
#  'Q104144947': 'Landau Test',
#  'Q104178966': 'Breland',
#  'Q1042': 'Seychelles',
#  'Q104218554': 'rock singer',
#  'Q104244010': 'JA21',
#  'Q1042498': 'Hunter Hayes',
#  'Q104266': 'Mel Brooks',
#  'Q1043527': 'Multilateral Investment Guarantee Agency',
#  'Q104358': 'Billie Holiday',
#  'Q104372': 'Doris Day',
#  'Q104378422': 'One Apus',
#  'Q104385201': 'Rumaan Alam',
#  'Q1044': 'Sierra Leone',
#  'Q104413873': 'Andrea Spendolini-Sirieix',
#  'Q104419402': 'Yusef Salaam',
#  'Q104434122': '18 years or older',
#  'Q1044427': 'Primetime Emmy Award',
#  'Q1045': 'Somalia',
#  'Q104520994': 'Dustin Wolf',
#  'Q104540693': '2023 FIFA U-17 World Cup',
#  'Q104568286': 'Marshall and Ross Von Erich',
#  'Q104621930': 'Jeremy Sochan',
#  'Q104639732': 'Kash Patel',
#  'Q104643359': 'Marvel Cinematic Universe Phase Five',
#  'Q104665671': 'WikiProject PCC Wikidata Pilot/Northwestern University Libraries',
#  'Q10467': 'FC Barcelona Atlètic',
#  'Q1046707': 'Casablanca Records',
#  'Q104680': 'colonel',
#  'Q104694359': 'WikiProject PCC Wikidata Pilot/Frick Art Reference Library',
#  'Q1047': 'Jawaharlal Nehru',
#  'Q104705419': '2021 storming of the United States Capitol',
#  'Q104708132': 'Jake Angeli',
#  'Q1047410': 'Walt Disney Animation Studios',
#  'Q104761': 'Bayer 04 Leverkusen',
#  'Q10479': 'Catherine, Princess of Wales',
#  'Q1048': 'Julius Caesar',
#  'Q1048129': '2008 Chinese milk scandal',
#  'Q104822927': '2023 Louisiana gubernatorial election',
#  'Q104839736': '0+',
#  'Q104839741': '6+',
#  'Q104839742': '15+',
#  'Q104839743': '12+',
#  'Q104842993': '2022 College Football Playoff National Championship',
#  'Q104845858': 'India national football team at the FIFA World Cup qualification',
#  'Q104856413': 'C. J. Stroud',
#  'Q104857564': 'Bharatiya Janata Party, Telangana',
#  'Q104858062': 'Jeo Baby',
#  'Q104867022': 'Damien Leone',
#  'Q104867414': 'Ryan Smith',
#  'Q104876413': 'William Afton',
#  'Q104876581': '2023 United States gubernatorial elections',
#  'Q104876724': '2023 Kentucky gubernatorial election',
#  'Q104878100': 'Queen Elizabeth II Platinum Jubilee Medal',
#  'Q104878647': 'Jordan Davis',
#  'Q104880303': 'Leave the World Behind',
#  'Q104880809': 'Slow Horses',
#  'Q104881913': 'The Curse',
#  'Q1048856': 'All in the Family',
#  'Q1048902': 'pitcher',
#  'Q1049': 'Sudan',
#  'Q1049171': 'England national under-18 association football team',
#  'Q1049176': 'England national under-20 association football team',
#  'Q104924327': '2022 Serbian general election',
#  'Q1049511': 'WhatsApp',
#  'Q1049545': 'Clash of the Titans',
#  'Q10497074': 'flight engineer',
#  'Q104979534': 'Munawar Faruqui',
#  'Q104994': 'Los Angeles County',
#  'Q104998020': 'piano performance',
#  'Q105': 'Monday',
#  'Q1050': 'Eswatini',
#  'Q105005611': 'Heather Ripley',
#  'Q105007708': 'Adarsh Gourav',
#  'Q105024779': 'Cherry Valentine',
#  'Q105027234': 'Print Collection',
#  'Q105031': 'Home Alone',
#  'Q105037400': 'Nobara Kugisaki',
#  'Q1050571': 'catcher',
#  'Q1050837': 'Ship of Theseus',
#  'Q10509939': 'gray hair',
#  'Q10510': 'Jenson Button',
#  'Q105102826': 'murders of Claudia Maupin and Oliver Northup',
#  'Q1051032': 'The Italian Job',
#  'Q105107179': 'guitar performance',
#  'Q10514': 'Fernando Alonso',
#  'Q105142115': 'Harrison Ruffin Tyler',
#  'Q1051840': 'Sarah Lawrence College',
#  'Q10520': 'David Beckham',
#  'Q1052025': 'PlayStation Store',
#  'Q105221': 'Dan Aykroyd',
#  'Q1052260': "New Year's Eve",
#  'Q1052281': 'trans woman',
#  'Q10526787': 'Wataru Endō',
#  'Q105275320': 'Steam Award for Labor of Love',
#  'Q1052913': 'respiratory syncytial virus',
#  'Q105293684': 'Ifeatu Melifonwu',
#  'Q105320475': 'Engineering Red',
#  'Q1053256': 'New History of Yuan',
#  'Q105338': 'Geert Wilders',
#  'Q105339055': 'honorary Fellow of the Royal College of Surgeons',
#  'Q1053574': 'executive producer',
#  'Q105359456': 'Ant-Man and the Wasp: Quantumania',
#  'Q1053668': 'Justicialist Party',
#  'Q105393903': 'John Kennedy',
#  'Q105412880': 'Volt Netherlands',
#  'Q105424921': '2023 Mississippi gubernatorial election',
#  'Q105438637': 'Paul Alexander',
#  'Q1054437': 'Yamata no Orochi',
#  'Q105447': 'Saturn Award',
#  'Q1054574': 'romance film',
#  'Q105470741': 'A.J. Ferrari',
#  'Q10547335': 'John McGinn',
#  'Q1054923': 'British Hong Kong',
#  'Q1055': 'Hamburg',
#  'Q105542333': 'Teddy Swims',
#  'Q105543609': 'musical work/composition',
#  'Q105549749': 'House of Gucci',
#  'Q105553568': 'Wednesday',
#  'Q105576149': '2024 CONCACAF Champions Cup',
#  'Q105582950': 'Parker Washington',
#  'Q105595817': 'Kumar Kushagra',
#  'Q105598': 'Die Hard',
#  'Q105605250': 'X',
#  'Q105605280': 'Adipurush',
#  'Q105612429': 'Tom Aspinall',
#  'Q1056240': 'Hugo Award for Best Dramatic Presentation, Long Form',
#  'Q1056244': 'Jim Rice',
#  'Q105627815': 'Rubi Rose',
#  'Q1056362': 'death of Caylee Anthony',
#  'Q105640076': 'Topside Test',
#  'Q105641628': 'Coates Test',
#  'Q1056843': "Alice's Restaurant",
#  'Q105698274': 'Mohammed Kaif',
#  'Q105700813': 'Russ Test',
#  'Q105701756': 'Tyrion Test',
#  'Q105702736': 'Tauriel Test',
#  'Q105704187': 'Fusa Tatsumi',
#  'Q105708928': 'Raleigh Becket Test',
#  'Q105725595': 'Lucky Aiyedatiwa',
#  'Q105726358': 'AfroBubbleGum Test',
#  'Q105729789': 'Celia Imrie Test',
#  'Q105776216': 'reverse Bechdel Test',
#  'Q1058': 'Narendra Modi',
#  'Q105802405': 'Dictionary of Women Worldwide',
#  'Q105806948': 'Napoleon',
#  'Q105816692': 'BubbleGum Test',
#  'Q1058395': 'Times Square Ball',
#  'Q1058731': 'Morgan',
#  'Q1058745': 'Chael Sonnen',
#  'Q105883400': 'The Whale',
#  'Q105887530': 'Tom Blyth',
#  'Q10588869': 'Moore',
#  'Q1058952': 'Scrooge',
#  'Q105913295': 'reverse Mako Mori test',
#  'Q105918665': 'reverse Waithe Test',
#  'Q105919675': 'reverse Landau Test',
#  'Q105936481': 'WikiProject PCC Wikidata Pilot/Harry Ransom Center',
#  'Q105958972': 'Notable Black American Women',
#  'Q105974284': 'Robert A. Wood',
#  'Q105976715': 'Michelle Salzman',
#  'Q10599': 'Sean Dyche',
#  'Q1059914': 'Death on the Nile',
#  'Q105993': 'Die Hard 2',
#  'Q106010': 'Christmas Eve',
#  'Q10602': 'Ashley Young',
#  'Q1060321': 'Gaussian integral',
#  'Q1060344': 'Luke Grimes',
#  'Q106039': 'Christian',
#  'Q106078330': 'Central Cee',
#  'Q10608114': 'Oklahoma Sooners football',
#  'Q1061': 'Gujarat',
#  'Q106111559': 'Babepedia',
#  'Q1061233': "L'Équipe Champion of Champions",
#  'Q1061257': '112',
#  'Q106193': 'Lars Ulrich',
#  'Q1062002': 'Assia Wevill',
#  'Q1062019': 'MTV Movie Award for Best Breakthrough Performance',
#  'Q1062026': 'MTV Movie Award for Best Villain',
#  'Q106221': 'James Horner',
#  'Q106247012': 'history of the Israeli–Palestinian conflict',
#  'Q106286632': 'Alaqua Cox',
#  'Q106291': 'Academy Award for Best Supporting Actor',
#  'Q106298476': 'Caitlin Clark',
#  'Q106298596': 'Salaar part 2',
#  'Q106301': 'Academy Award for Best Supporting Actress',
#  'Q1063119': 'Super Mario RPG',
#  'Q106323898': 'Pavlenkov Encyclopedic Dictionary',
#  'Q10633': 'Queen Elizabeth, The Queen Mother',
#  'Q1063412': 'Ranbir Kapoor',
#  'Q1063567': 'Sellafield',
#  'Q106369192': 'Kyle LeDuc',
#  'Q106376206': 'Coi Leray',
#  'Q106378786': 'Lainey Wilson',
#  'Q106392679': 'Coyote vs. Acme',
#  'Q1064120': 'Bobby Lee',
#  'Q1064123': 'A Christmas Carol',
#  'Q106414142': 'Zoey Stark',
#  'Q106447927': 'Ebanie Bridges',
#  'Q1064530': 'Jingle All the Way',
#  'Q106456476': 'Sylvia Bloom',
#  'Q106464255': 'Impa Kasanganay',
#  'Q10648': 'Gordon Brown',
#  'Q106481': 'Alan Rickman',
#  'Q1064838': 'The Family Stone',
#  'Q1064920': 'Melanie',
#  'Q1064978': 'MTV Video Music Award for Best Male Video',
#  'Q1065': 'United Nations',
#  'Q106500': 'sambo',
#  'Q106508': 'Gérard Depardieu',
#  'Q106514': 'River Phoenix',
#  'Q106514204': 'Greensill scandal',
#  'Q106514711': 'Men',
#  'Q106517969': 'Crystal Award',
#  'Q106522145': 'Max Miller',
#  'Q1065229': 'Super Bowl XXX',
#  'Q106543540': 'Sam Bankman-Fried',
#  'Q1065444': 'kaiju',
#  'Q106548888': 'European Super League',
#  'Q1065520': 'Sam Lake',
#  'Q106554732': 'Lim Hui Ying',
#  'Q1065651': 'MTV Video Music Award for Video of the Year',
#  'Q106582931': 'Squid Game',
#  'Q106625072': '2023 Dutch general election',
#  'Q106626612': 'Adin Ross',
#  'Q106629302': 'Yasmin Finney',
#  'Q106639064': 'Friends: The Reunion',
#  'Q106648': 'Fleetwood Mac',
#  'Q1066501': 'Charles Woodson',
#  'Q106652173': '2023 United States elections',
#  'Q1066551': 'Charles Koch',
#  'Q106658419': 'Damar Hamlin',
#  'Q1066681': 'Japanese battleship Haruna',
#  'Q106679014': 'The White Lotus',
#  'Q1066873': 'Meet Me in St. Louis',
#  'Q10669499': 'naval officer',
#  'Q106696935': 'Evening Standard Theatre Award for Best Actress',
#  'Q106727050': 'Metropolitan Museum of Art Tagging Vocabulary',
#  'Q106748471': 'Love Has Won',
#  'Q1067697': 'Kharp',
#  'Q106770023': 'Zach Bryan',
#  'Q106771241': 'Vigil',
#  'Q106787730': 'American Women Writers',
#  'Q10680': 'PlayStation 2',
#  'Q106800': 'Academy Award for Best Animated Feature',
#  'Q106805131': 'Anthony Elanga',
#  'Q1068063': 'National Gallery of Canada',
#  'Q106807': 'Magnus Carlsen',
#  'Q106810295': 'Aryan Dutt',
#  'Q106816679': '2023 Karnataka Legislative Assembly election',
#  'Q106816701': '2023 Chhattisgarh Legislative Assembly election',
#  'Q106816702': '2023 Rajasthan Legislative Assembly election',
#  'Q106817973': 'Zach Edey',
#  'Q106818294': 'Keegan Murray',
#  'Q10683': 'PlayStation 3',
#  'Q106830311': 'Yellowjackets',
#  'Q106839925': 'Khaby Lame',
#  'Q10686': 'Belfast',
#  'Q106871': 'Die Hard with a Vengeance',
#  'Q1068752': 'Howard University',
#  'Q1069127': 'lapsed Catholic',
#  'Q10693': 'periodic table',
#  'Q106942': 'Candice Bergen',
#  'Q106946845': 'Coventry City 2–2 Bristol City',
#  'Q106962940': 'Hamad Međedović',
#  'Q106993197': 'Jaxson Dart',
#  'Q106993511': 'The Lazarus Project',
#  'Q106997': 'Jamie Lee Curtis',
#  'Q1070': 'Ahmedabad',
#  'Q107010812': 'Gary Hilton',
#  'Q107015966': '2023 Mizoram Legislative Assembly election',
#  'Q107016378': '2023 Madhya Pradesh Legislative Assembly election',
#  'Q107016831': '2023 Telangana Legislative Assembly election',
#  'Q10702': 'Who Shot Mr. Burns?',
#  'Q1070333': 'University of Arkansas',
#  'Q107045454': 'Masked Goddess',
#  'Q107072432': 'From',
#  'Q10708': 'Red Hot Chili Peppers',
#  'Q107104135': '2024 Andhra Pradesh Legislative Assembly election',
#  'Q107104310': 'The Tourist',
#  'Q107104814': 'Josh Pederson',
#  'Q107126': 'Arlington County',
#  'Q10717': 'Georgetown',
#  'Q107175474': 'Spaceman',
#  'Q107178269': 'Kenneth Lofton Jr.',
#  'Q107187662': 'American Horror Stories',
#  'Q107208649': 'Avatar: Frontiers of Pandora',
#  'Q107210110': 'The Lord of the Rings: The War of the Rohirrim',
#  'Q107210866': 'Mali',
#  'Q1072120': 'Missile Technology Control Regime',
#  'Q1072383': 'Nicola Roberts',
#  'Q107249': 'Tony Shalhoub',
#  'Q10725': 'Troy Deeney',
#  'Q107258': 'Academy Award for Best Writing, Adapted Screenplay',
#  'Q10726168': 'history of Turku',
#  'Q1072699': 'Maurice Tillet',
#  'Q107287943': 'British Post Office scandal',
#  'Q107288927': 'Battlegrounds Mobile India',
#  'Q10729319': 'list of prime ministers of the United Kingdom',
#  'Q107304994': 'Maureen Flavin Sweeney',
#  'Q107312991': 'Prasanth Varma',
#  'Q107324616': "The Marsh King's Daughter",
#  'Q10732476': 'art collector',
#  'Q107365': 'Manuel Neuer',
#  'Q107366114': 'Nightbirde',
#  'Q10737': 'suicide',
#  'Q107377183': 'Julia Hart',
#  'Q10738': 'Dwayne Johnson',
#  'Q107390449': 'Kraven the Hunter',
#  'Q107391656': 'Chris Bumstead',
#  'Q107392911': 'Gettr',
#  'Q107404742': 'Quinn Ewers',
#  'Q10745598': '1958 Lituya Bay earthquake and megatsunami',
#  'Q107463278': 'Anant V Joshi',
#  'Q107463341': 'Spirited',
#  'Q107472639': 'Expo 2030',
#  'Q107510346': 'RoboCop: Rogue City',
#  'Q1075293': 'Irish Americans',
#  'Q107542665': 'Steam Deck',
#  'Q107555689': "2023 Men's FIH Hockey Junior World Cup",
#  'Q1075651': 'keyboardist',
#  'Q107570416': 'PinkPantheress',
#  'Q107595999': 'The Vatican Rag',
#  'Q107610336': 'The Exorcist: Believer',
#  'Q10762848': 'Officer of the Order of the British Empire',
#  'Q107730': 'Vince Vaughn',
#  'Q1077393': 'Chris Kamara',
#  'Q1077554': 'Chris Metzen',
#  'Q1077603': 'mesothelioma',
#  'Q107805133': 'Kim Keon-hee',
#  'Q107808351': 'Blue Beetle',
#  'Q10780973': 'WikiProject Ukraine',
#  'Q1079': 'Breaking Bad',
#  'Q1079023': 'championship',
#  'Q1079140': 'Indiana University Bloomington',
#  'Q107930811': 'Tino Livramento',
#  'Q107957': 'Alexander Haig',
#  'Q107969593': 'She Said',
#  'Q107974512': '2023 BWF World Tour Finals',
#  'Q107985608': 'James Trafford',
#  'Q10798782': 'television actor',
#  'Q108': 'January',
#  'Q10800557': 'film actor',
#  'Q108047434': 'James Wan',
#  'Q10806': 'September 11 attacks',
#  'Q108069627': 'Dandadan',
#  'Q108086029': 'Asteroid City',
#  'Q108091695': 'Franco Cozzo',
#  'Q108094403': 'John Textor',
#  'Q108106738': 'Olivia Dean',
#  'Q108111889': 'Gavi',
#  'Q1081491': 'football codes',
#  'Q108270': 'Warwick Davis',
#  'Q108273534': 'Saints Row',
#  'Q108283': 'Alan Arkin',
#  'Q108314793': 'Retribution',
#  'Q108324450': 'Matt Ammendola',
#  'Q10833314': 'tennis player',
#  'Q1083432': 'Kieran Trippier',
#  'Q108370415': 'dead Internet theory',
#  'Q108373707': 'Omid Scobie',
#  'Q108405509': 'Jameson Williams',
#  'Q108417001': 'Alan Wake II',
#  'Q10841764': 'Formula One driver',
#  'Q108444804': 'The Menu',
#  'Q1084472': 'Christopher',
#  'Q108454548': 'Liberty Advances',
#  'Q108456719': 'Wonka',
#  'Q108459058': 'Sutton Stracke',
#  'Q108479502': 'Spider-Man 2',
#  'Q108489502': 'Chloe Bailey',
#  'Q1085': 'Prague',
#  'Q1085001': 'ballroom dance',
#  'Q108525388': 'Zay Flowers',
#  'Q108526760': 'Bailey Zappe',
#  'Q10853588': 'Kamala Harris',
#  'Q1085383': 'offensive tackle',
#  'Q108541200': 'Will Levis',
#  'Q108541675': 'Sniffies',
#  'Q10855195': 'Officer of the Legion of Honour',
#  'Q10855212': 'Commander of the Legion of Honour',
#  'Q10855226': 'Grand Cross of the Legion of Honour',
#  'Q10855271': 'Knight of the Legion of Honour',
#  'Q108555657': 'The Creed Brothers',
#  'Q10855755': 'Takumi Kitamura',
#  'Q108559509': 'Kin',
#  'Q108576604': 'Jaxon Smith-Njigba',
#  'Q108586048': 'Al Naslaa',
#  'Q10859': 'Spanish Civil War',
#  'Q10859343': 'Harris',
#  'Q108602387': 'Kenneth Walker III',
#  'Q108607605': 'Sam Thompson',
#  'Q108622': 'Talia Shire',
#  'Q108628759': 'Joker: Folie à Deux',
#  'Q1086291': 'Christophe Beck',
#  'Q108631': 'Katherine',
#  'Q10863578': 'Kelvin Gastelum',
#  'Q10864048': 'first-level administrative division',
#  'Q108660585': 'Tanner Mordecai',
#  'Q108662765': '2023–24 UEFA Europa League',
#  'Q108663369': '2023–24 UEFA Europa Conference League',
#  'Q108671102': 'The Super Mario Bros. Movie',
#  'Q108672702': 'UEFA Euro 2024 qualifying',
#  'Q1086863': 'columnist',
#  'Q108690643': 'Lewis Dobbin',
#  'Q1087066': 'list of Mayday episodes',
#  'Q10871364': 'baseball player',
#  'Q10873124': 'chess player',
#  'Q108739709': 'Dark Harvest',
#  'Q10874': 'blindness',
#  'Q108745': 'Ghostbusters',
#  'Q108756568': 'Harnaaz Sandhu',
#  'Q108757235': 'Grand Theft Auto: The Trilogy – The Definitive Edition',
#  'Q108760382': 'Poor Things',
#  'Q10876842': 'Chinese cuisine',
#  'Q108779860': "Casey O'Neill",
#  'Q1087811': 'chronic wasting disease',
#  'Q1088': 'blue',
#  'Q108830207': 'Sam LaPorta',
#  'Q108839629': "2021 Ballon d'Or",
#  'Q108839994': 'Oppenheimer',
#  'Q1088453': 'Chrysalis Records',
#  'Q108846751': 'Emma Grede',
#  'Q108864780': 'FTX',
#  'Q1088765': 'ESPN Monday Night Football',
#  'Q108878513': 'Caleb Williams',
#  'Q108887921': '2024 United States Senate election in West Virginia',
#  'Q108911599': 'Loopy Godinez',
#  'Q108913383': 'J. J. McCarthy',
#  'Q108913483': 'Reptile',
#  'Q108913590': 'Ladd McConkey',
#  'Q108935': 'Mary Steenburgen',
#  'Q108940120': 'Paul Karason',
#  'Q108940169': 'Will Rogers',
#  'Q108940282': 'Haunted Mansion',
#  'Q108941': 'Carrie Fisher',
#  'Q108977': 'list of countries by GDP (nominal) per capita',
#  'Q109044799': 'Opinion polling for the next Dutch general election',
#  'Q10904959': 'Grand Cross Special Class of the Order of Merit of the Federal Republic of Germany',
#  'Q10905105': 'Grand Cross 1st class of the Order of Merit of the Federal Republic of Germany',
#  'Q10905276': "Commander's Cross of the Order of Merit of the Federal Republic of Germany",
#  'Q1091031': 'MTV Video Music Award for Best Female Video',
#  'Q109106357': 'Morgan Wade',
#  'Q1091237': 'David Armstrong-Jones, 2nd Earl of Snowdon',
#  'Q109170561': 'Kyle Allen',
#  'Q1092066': 'If I Should Fall from Grace with God',
#  'Q109228976': "Butcher's Crossing",
#  'Q109228991': 'Dune: Part Two',
#  'Q109232': 'Rosanna Arquette',
#  'Q1092460': 'surreal humour',
#  'Q109255401': 'YRF Spy Universe',
#  'Q109259869': 'Ahmed Nawaf Al-Ahmad Al-Sabah',
#  'Q109265764': 'Miss Universe 2022',
#  'Q10927615': 'left-handed shot',
#  'Q109284173': 'Hocus Pocus 2',
#  'Q1093085': 'The Big Heat',
#  'Q109317158': 'Matt Araiza',
#  'Q109323149': '2023 Formula One World Championship',
#  'Q109340489': 'Survivor Series WarGames',
#  'Q109382106': 'Sai Sudharsan',
#  'Q1093829': 'city in the United States',
#  'Q1093910': 'City College of New York',
#  'Q1094751': 'Claire',
#  'Q109510938': 'Travon Walker',
#  'Q1095301': 'Clare Grogan',
#  'Q109535238': 'Ganapath',
#  'Q1095395': 'Clarence Derwent Awards',
#  'Q109559532': 'Rustin',
#  'Q109561827': 'Moms for Liberty',
#  'Q109567468': 'Melissa Caddick',
#  'Q109570622': 'Braelon Allen',
#  'Q109579289': 'Theodore Conrad',
#  'Q109591569': 'Spotify Wrapped',
#  'Q109608844': 'Avatar: The Last Airbender',
#  'Q10962': 'rugby league',
#  'Q109620992': "Please Don't Destroy",
#  'Q109628790': 'Annie Rauwerda',
#  'Q109647832': 'Gulf States',
#  'Q109657967': 'Ian Garry',
#  'Q109658714': 'Pat Sabatini',
#  'Q109659531': 'Roony Bardghji',
#  'Q109671908': 'Prince of the United Kingdom',
#  'Q109686856': 'To Be Loved',
#  'Q10968813': 'jay',
#  'Q109701344': 'Guntur Kaaram',
#  'Q109733304': 'psychological thriller film',
#  'Q1097348': 'InterCom',
#  'Q1097498': 'ruler',
#  'Q1097511': 'J. J. Watt',
#  'Q109805561': 'Redin Kingsley',
#  'Q109849794': 'James Cook',
#  'Q109850709': 'Berlin',
#  'Q109853508': 'Bryan Zaragoza',
#  'Q109875605': '2024 elections in India',
#  'Q109901438': 'Reacher',
#  'Q109905035': 'Cameron Dicker',
#  'Q109905391': 'Cora Jade',
#  'Q109914046': 'Merry Christmas',
#  'Q109916309': 'Yūta Okkotsu',
#  'Q10993': 'Tiger Woods',
#  'Q109974318': 'T. J. Gnanavel',
#  'Q110028874': 'The Game Awards 2022',
#  'Q110038173': '2023 AFC Cup',
#  'Q110043': 'The Birds',
#  'Q110056988': 'Nella Rose',
#  'Q110060429': '2023 AFC Champions League',
#  'Q11007': 'House of Lords',
#  'Q110084960': 'Jerma985',
#  'Q110098231': 'Nolan Smith',
#  'Q110098618': 'Nardo Wick',
#  'Q110138': 'Top Gun',
#  'Q110143785': 'David Fuller',
#  'Q1101443': "National Women's Soccer League",
#  'Q110145': 'MTV Movie & TV Awards',
#  'Q11015': 'snooker',
#  'Q110155318': 'Jimi Famurewa',
#  'Q110156249': 'The Fall of the House of Usher',
#  'Q1101938': 'Clive Davis',
#  'Q110206584': 'Call of Duty: Modern Warfare II',
#  'Q1102307': 'Lady Justice',
#  'Q110252005': '2024 United States elections',
#  'Q110269029': 'Aria Mia Loberti',
#  'Q110275941': 'Jesse Rodriguez',
#  'Q110278132': "Single's Inferno",
#  'Q11030': 'journalism',
#  'Q110321987': '2025 ICC Champions Trophy',
#  'Q110337160': "Aidan O'Connell",
#  'Q110354': 'The Great Escape',
#  'Q11036': 'The Rolling Stones',
#  'Q110362884': 'list of American films of 2023',
#  'Q110362903': 'list of Bollywood films of 2023',
#  'Q110367996': 'Wordle',
#  'Q11038927': 'National Film Award for Best Actor',
#  'Q110393266': 'Jaren Hall',
#  'Q110401826': 'Jake Ferguson',
#  'Q110420867': 'Jordan Travis',
#  'Q110442394': 'Larsa Pippen',
#  'Q110460526': 'KaVontae Turpin',
#  'Q110466658': 'Oscar Bobb',
#  'Q110471679': 'honorary doctor of the University of Miami',
#  'Q110483835': 'Jobe Bellingham',
#  'Q110486192': 'Nestor Irankunda',
#  'Q110487162': 'Lewis Hall',
#  'Q110527703': 'Samir Shah',
#  'Q110530811': 'BigBrotherAwards',
#  'Q110550377': 'killing of Ashling Murphy',
#  'Q110560919': 'Substitute Teacher',
#  'Q110582780': 'Steam Award for Game of the Year',
#  'Q110583757': 'Steam Award for Outstanding Story-Rich Game',
#  'Q11059': 'Sanskrit',
#  'Q110602969': 'All the Light We Cannot See',
#  'Q110613097': 'Myanmar civil war',
#  'Q110613186': 'Audie Award for Narration by the Author',
#  'Q110614173': 'Gyeongseong Creature',
#  'Q110617876': 'The Creator',
#  'Q11063': 'astronomer',
#  'Q110633214': 'Legends League Cricket',
#  'Q110640752': 'Ryan Poles',
#  'Q110644260': 'Endrick Felipe',
#  'Q110664384': 'Creed III',
#  'Q1107': 'anime',
#  'Q1107314': 'MBC 4',
#  'Q110732481': 'Freelance',
#  'Q110741097': 'Dave Ziegler',
#  'Q110763745': 'Terri Schiavo case',
#  'Q110775465': 'Stefany Ferrer Van Ginkel',
#  'Q11081': "Alzheimer's disease",
#  'Q110825847': 'Shavkat Rakhmonov',
#  'Q110835368': 'Gujarat Titans',
#  'Q110839': 'Jens Söring',
#  'Q110842446': 'Meg 2: The Trench',
#  'Q11085': "Parkinson's disease",
#  'Q110853869': 'GroenLinks–PvdA',
#  'Q1109032': 'college football',
#  'Q110903857': 'Christian Watson',
#  'Q1109260': 'Jennifer Flavin',
#  'Q110937657': "2024 AFC Women's Olympic Qualifying Tournament",
#  'Q110938009': 'Arthur the King',
#  'Q110970104': 'Luke Littler',
#  'Q110970890': 'Quantum Realm',
#  'Q110995393': 'Ethan Mbappé',
#  'Q1109976': 'Eastern European Summer Time',
#  'Q110999040': 'Russian invasion of Ukraine',
#  'Q111': 'Mars',
#  'Q111008873': 'The Killer',
#  'Q111016177': 'Vitor Roque',
#  'Q111031775': 'Propnight',
#  'Q1110944': 'England national association football B team',
#  'Q1111310': 'Directors Guild of America Award',
#  'Q111133839': 'NCIS: Sydney',
#  'Q111148664': 'Ormond Beatty',
#  'Q111149342': 'Heart of Stone',
#  'Q11116': 'Ruth Bader Ginsburg',
#  'Q111170246': 'Violent Night',
#  'Q111181225': 'Aditi Saigal',
#  'Q111181799': 'LIV Golf',
#  'Q1112005': 'Queen Latifah',
#  'Q111208159': '2023 United Nations Climate Change Conference',
#  'Q111240': 'Jim Lovell',
#  'Q111241092': 'film reboot',
#  'Q11124885': 'martial artist',
#  'Q111270010': 'The Color Purple',
#  'Q111280241': 'Warren Zaïre-Emery',
#  'Q111299232': 'Millie Gibson',
#  'Q111309338': '2023–24 UEFA Champions League',
#  'Q11132': "Sandra Day O'Connor",
#  'Q111336539': 'Nico Paz',
#  'Q111342049': 'Grant Amato',
#  'Q1113428': 'Filmfare Award for Best Director',
#  'Q111366053': 'Alejandro Garnacho',
#  'Q111366943': 'Stavros Halkias',
#  'Q11138': 'Samuel Alito',
#  'Q111381707': 'Le Sserafim',
#  'Q111385820': 'Kate Bishop',
#  'Q111421263': 'Solo Sikoa',
#  'Q111436': 'Elmer Bernstein',
#  'Q111443584': 'Las Vegas Grand Prix',
#  'Q1114461': 'comics character',
#  'Q111461784': '2023 MLS Cup Playoffs',
#  'Q111503908': 'Vito Coppola',
#  'Q1115050': 'United States Army Command and General Staff College',
#  'Q11151': 'FA Cup',
#  'Q111514224': 'Walker Scobell',
#  'Q11152': 'EFL Cup',
#  'Q111528279': 'The Boys in the Boat',
#  'Q111536390': 'Bo Melton',
#  'Q111537648': 'Huh Yun-jin',
#  'Q111568723': "2024 ICC Men's T20 World Cup",
#  'Q11160831': 'Anupam Roy',
#  'Q111629600': 'Rebel Moon — Part One: A Child of Fire',
#  'Q11166731': 'Justin',
#  'Q111669794': 'Pearl',
#  'Q111670916': 'Leave the World Behind',
#  'Q11167678': 'Nathan',
#  'Q111676994': 'Echo',
#  'Q111677117': 'Madame Web',
#  'Q1116777': 'Von Erich family',
#  'Q111677965': 'Ironmouse',
#  'Q111698612': 'Angel Reese',
#  'Q111722535': 'monarch of the United Kingdom of Great Britain and Ireland',
#  'Q111744347': 'Sister Death',
#  'Q111784581': 'The Nun II',
#  'Q111805023': 'DaRon Bland',
#  'Q111811603': 'The Judgment Day',
#  'Q111812475': 'PDC World Darts Championship 2023',
#  'Q111830176': 'Finestkind',
#  'Q11184': 'Julian calendar',
#  'Q11185210': '118',
#  'Q111889154': '2024–25 UEFA Nations League',
#  'Q111901584': 'Padmini Devi',
#  'Q111902589': 'Jake Daniels',
#  'Q111905335': 'Bosch: Legacy',
#  'Q111907282': 'Maestro',
#  'Q111907987': 'Fifteenth Doctor',
#  'Q1119151': 'Clark',
#  'Q1119157': 'Frankie Dettori',
#  'Q111918059': 'IF',
#  'Q111936393': '2023 Houston mayoral election',
#  'Q111938449': 'Indian Renewable Energy Development Agency Limited',
#  'Q111947838': 'The Santa Clauses',
#  'Q111951587': 'Anders Carlson',
#  'Q111952120': 'Billboard 21 Under 21',
#  'Q111956156': 'list of Yellowstone (American TV series) episodes',
#  'Q111962910': 'The Burial',
#  'Q111967146': 'Tulsa King',
#  'Q111976143': 'Alison Oliver',
#  'Q111983059': 'Tchia',
#  'Q11201': 'Supreme Court of the United States',
#  'Q112014': 'Cabinet of the United Kingdom',
#  'Q112030428': 'Jack Jones',
#  'Q112054623': 'In the Land of Saints and Sinners',
#  'Q112055': 'Cyber Monday',
#  'Q112061885': 'Steven Cheung',
#  'Q112063616': 'Marvin Harrison Jr.',
#  'Q112078051': 'Silent Night',
#  'Q112099': 'island country',
#  'Q112114745': 'The Holdovers',
#  'Q112128621': 'Crown Jewel',
#  'Q112130689': 'Six Monkey War Quechquemitl',
#  'Q112144412': 'esports discipline',
#  'Q112162297': 'Winnie-the-Pooh: Blood and Honey',
#  'Q112168901': 'Nyad',
#  'Q11217157': 'Roelof van der Merwe',
#  'Q11218': 'United States Marine Corps',
#  'Q112182964': 'UEFA Euro 2024 qualifying play-offs',
#  'Q112183099': 'Scream VI',
#  'Q112186865': 'Lawrence Bishnoi',
#  'Q112193': 'Gaston Glock',
#  'Q112193867': 'class of disease',
#  'Q11220': 'United States Navy',
#  'Q11220194': 'Dawn of the Planet of the Apes',
#  'Q112223638': 'Twisted Metal',
#  'Q112228497': 'Trinidad Petroleum Holdings',
#  'Q11223': 'United States Air Force',
#  'Q112241213': 'honorary doctor of the Berklee College of Music',
#  'Q112243': 'Academy Award for Best Original Song',
#  'Q112243071': 'Lokesh Cinematic Universe',
#  'Q112252453': '2023 United States state legislative elections',
#  'Q112307': 'Lena Horne',
#  'Q112307747': 'Strong Girl Nam-soon',
#  'Q112322116': 'Captain America: Brave New World',
#  'Q112329906': 'Théo Zidane',
#  'Q1123353': "Battle of Rorke's Drift",
#  'Q112339753': 'Michael Beale',
#  'Q1123613': 'Schuko',
#  'Q11237': 'Nelson Rockefeller',
#  'Q112375': 'Galápagos National Park',
#  'Q1124': 'Bill Clinton',
#  'Q1124061': 'Concord Records',
#  'Q112430183': 'Kalki 2898 AD',
#  'Q1124341': 'Harriet',
#  'Q1124849': 'Verve Records',
#  'Q112501462': 'Isiah Pacheco',
#  'Q1125262': 'Mad Max 2',
#  'Q112536': 'Joey King',
#  'Q11253984': 'Stephen Thompson',
#  'Q1125399': 'NBA Most Improved Player Award',
#  'Q11255': 'Microsoft Offic',
#  'Q11256': 'Fidel Castro',
#  'Q112577': 'The Twelve Days of Christmas',
#  'Q112580267': 'Aryan Simhadri',
#  'Q112581616': 'Bailey Zimmerman',
#  'Q112587272': 'Squid Game: The Challenge',
#  'Q1125994': 'Congressional Progressive Caucus',
#  'Q112617712': 'Final Fantasy VII Rebirth',
#  'Q112618750': 'Cocoon',
#  'Q112623392': 'Gen V',
#  'Q112624769': 'Josh Andres Rivera',
#  'Q1126393': 'Mizo National Front',
#  'Q112648424': "2022 Ballon d'Or",
#  'Q1126563': 'Order of St. Andrew',
#  'Q112669126': 'Mariah May',
#  'Q11268': 'United States Congress',
#  'Q11269': "New Year's Eve",
#  'Q112761982': 'The Bear',
#  'Q1127675': '2007 Cricket World Cup',
#  'Q11279730': 'Kristen',
#  'Q112801489': 'Elemental',
#  'Q112805534': 'Anna Paulina Luna',
#  'Q112811482': 'Damsel',
#  'Q112813857': 'Jarell Quansah',
#  'Q112818492': 'Pete Wicks',
#  'Q112827349': 'Will Hardy',
#  'Q112845099': 'Umar Johnson',
#  'Q1128631': 'Leeds United F.C.',
#  'Q112872244': '2023 Serbian parliamentary election',
#  'Q112892826': 'Parker Family Saga',
#  'Q1129089': 'Great Molasses Flood',
#  'Q112909147': 'Gran Turismo',
#  'Q112912851': '2024 AFC U-23 Asian Cup',
#  'Q1129487': 'Screen Actors Guild Award for Outstanding Performance by a Female Actor in a Leading Role',
#  'Q112957924': 'Ted',
#  'Q1129595': 'Spain national under-21 association football team',
#  'Q112965645': 'symptom or sign',
#  'Q112967552': 'Sandra Douglass Morgan',
#  'Q11296761': 'kickboxer',
#  'Q112980589': '2023 Copa Libertadores',
#  'Q11299': 'Manhattan',
#  'Q11303': 'skyscraper',
#  'Q11303721': 'golfer',
#  'Q113043714': 'Ferrari',
#  'Q113055140': 'Chen Xiaocui',
#  'Q113068': 'Hungarian Order of Merit',
#  'Q113080784': 'ECHO Awards',
#  'Q1130849': 'Liverpool F.C.',
#  'Q113089775': 'Spencer Webb',
#  'Q1130978': 'Maxwell Award',
#  'Q113110570': 'Fellow Travelers',
#  'Q113114887': 'Monarch: Legacy of Monsters',
#  'Q113114997': 'Killing of Moriah Wilson',
#  'Q113135527': 'Saltburn',
#  'Q1131356': 'Theatre World Award',
#  'Q113144658': 'Welcome to Wrexham',
#  'Q113145171': 'type of chemical entity',
#  'Q1131650': 'House of Carters',
#  'Q1131761': 'White Christmas',
#  'Q1131772': 'Saturn Award for Best Science Fiction Film',
#  'Q113184832': 'Kenan Yıldız',
#  'Q113189277': 'NewJeans',
#  'Q113193951': 'Zara McDermott',
#  'Q1131942': 'Tokugawa Tsunenari',
#  'Q113202416': 'Venu Chitale',
#  'Q113209507': 'creative and professional writing',
#  'Q1132113': 'Test cricket',
#  'Q11322124': 'list of leading goalscorers for the France national football team',
#  'Q1132346': 'North Carolina State University',
#  'Q113246175': 'Marina Stakusic',
#  'Q113252225': 'Kyle McCord',
#  'Q1132612': 'Anita Dobson',
#  'Q113281347': 'Marvel Cinematic Universe Phase Six',
#  'Q113282389': "2026 ICC Men's T20 World Cup",
#  'Q113292798': 'The Multiverse Saga',
#  ...}

# %%
rel_dataframe = pd.DataFrame({
    "ID" : rel_labels.keys(),
    "name" : rel_labels.values(),
}).set_index('ID')
rel_dataframe
# Out:
#                             name
# ID
# P1001    applies to jurisdiction
# P101               field of work
# P102   member of political party
# P1027               conferred by
# P103             native language
# ...                          ...
# P97                  noble title
# P9714                taxon range
# P9866                GRAC rating
# P991        successful candidate
# P9929                    madhhab
#
# [450 rows x 1 columns]

# %%
entity_dataframe = pd.DataFrame({
    "ID" : entity_labels.keys(),
    "name" : entity_labels.values(),
}).set_index('ID')
entity_dataframe
# Out:
#                                         name
# ID
# L252247-F2                   Label not found
# L371                         Label not found
# L484                         Label not found
# L485                         Label not found
# L615860-F1                   Label not found
# ...                                      ...
# Q99774629                       Iman Vellani
# Q99925317                       Arch Manning
# Q99943130                         Gypsy Rose
# Q99951011   International Space Hall of Fame
# Q99960947                        Zach Wilson
#
# [13412 rows x 1 columns]

# %%
#deleting unknown label
entity_dataframe = entity_dataframe.query(' name != "Label not found"')

# %%
entity_dataframe.to_csv("data/common_entity.csv", index = False)
df_most_clicked_reduced.to_csv("data/df_most_clicked_reduced.csv", index = False)
rel_dataframe.to_csv("data/common_relations.csv", index = False)
